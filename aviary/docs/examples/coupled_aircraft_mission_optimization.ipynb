# %% [markdown]
# # Coupled Aircraft-Mission Optimization
#
# One of the most exciting features of Aviary is the ability to formulate and solve coupled aircraft-mission design optimization problems.
# Here, we mean that we are finding the optimal aircraft design parameters while simultaneously finding the optimal mission trajectory.
# The reason why this is so valuable is that it enables exploration of a larger design space much more efficiently.
#
# Solving coupled design-mission problems leads to optimal designs that would not be findable without simultaneously designing the aircraft and the trajectory.
# This is especially useful for unconventional aircraft designs, operations with complex missions, and many more future-focused studies than what is commonly flying today.
#
# This doc page builds up a coupled design problem and explains what we're doing along the way.
# This process is relatively straightforward in Aviary.
# We will briefly discuss the optimal results, but that is not necessarily the focus here.
# Instead, we want to showcase how to do a simple coupled design study in Aviary.
#
# You can use this as a starting point for your own exciting aircraft and mission design studies.
#
# ## Problem Definition and Explanation
#
# We will use a conventional single-aisle commercial aircraft design as our starting point.
# For all of these examples we allow the aircraft to be sized by the optimizer.
# This means the gross takeoff weight is controlled to meet a mass balance.
#
# We will perform four different optimization cases as part of this study:
#
# - fixed mission profile, fixed aircraft wing aspect ratio
# - fixed mission profile, optimized aircraft wing aspect ratio
# - optimized mission profile, fixed aircraft wing aspect ratio
# - optimized mission profile, optimized aircraft wing aspect ratio
#
# We'll provide more detail individually for each case.
#
# When we call Aviary, we will use a common `phase_info` object that we modify for each optimization case shown here:

# %%
phase_info = {
    "pre_mission": {"include_takeoff": False, "optimize_mass": True},
    "climb_1": {
        "subsystem_options": {"core_aerodynamics": {"method": "computed"}},
        "user_options": {
            "optimize_mach": False,
            "optimize_altitude": False,
            "polynomial_control_order": 1,
            "num_segments": 5,
            "order": 3,
            "solve_for_distance": False,
            "initial_mach": (0.2, "unitless"),
            "final_mach": (0.72, "unitless"),
            "mach_bounds": ((0.18, 0.84), "unitless"),
            "initial_altitude": (0.0, "ft"),
            "final_altitude": (32500.0, "ft"),
            "altitude_bounds": ((0.0, 33000.0), "ft"),
            "throttle_enforcement": "path_constraint",
            "fix_initial": True,
            "constrain_final": False,
            "fix_duration": False,
            "initial_bounds": ((0.0, 0.0), "min"),
            "duration_bounds": ((35.0, 105.0), "min"),
        },
        "initial_guesses": {"times": ([0, 70], "min")},
    },
    "cruise": {
        "subsystem_options": {"core_aerodynamics": {"method": "computed"}},
        "user_options": {
            "optimize_mach": False,
            "optimize_altitude": False,
            "polynomial_control_order": 1,
            "num_segments": 5,
            "order": 3,
            "solve_for_distance": False,
            "initial_mach": (0.72, "unitless"),
            "final_mach": (0.80, "unitless"),
            "mach_bounds": ((0.7, 0.84), "unitless"),
            "initial_altitude": (32500.0, "ft"),
            "final_altitude": (36000.0, "ft"),
            "altitude_bounds": ((32000.0, 36500.0), "ft"),
            "throttle_enforcement": "boundary_constraint",
            "fix_initial": False,
            "constrain_final": False,
            "fix_duration": False,
            "initial_bounds": ((35.0, 105.0), "min"),
            "duration_bounds": ((91.5, 274.5), "min"),
        },
        "initial_guesses": {"times": ([70, 183], "min")},
    },
    "descent_1": {
        "subsystem_options": {"core_aerodynamics": {"method": "computed"}},
        "user_options": {
            "optimize_mach": False,
            "optimize_altitude": False,
            "polynomial_control_order": 1,
            "num_segments": 5,
            "order": 3,
            "solve_for_distance": False,
            "initial_mach": (0.72, "unitless"),
            "final_mach": (0.21, "unitless"),
            "mach_bounds": ((0.19, 0.84), "unitless"),
            "initial_altitude": (36000.0, "ft"),
            "final_altitude": (0.0, "ft"),
            "altitude_bounds": ((0.0, 36500.0), "ft"),
            "throttle_enforcement": "path_constraint",
            "fix_initial": False,
            "constrain_final": True,
            "fix_duration": False,
            "initial_bounds": ((126.5, 379.5), "min"),
            "duration_bounds": ((25.0, 75.0), "min"),
        },
        "initial_guesses": {"times": ([253, 50], "min")},
    },
    "post_mission": {
        "include_landing": False,
        "constrain_range": True,
        "target_range": (2080, "nmi"),
    },
}

# %% [markdown]
# Now, let us explain each case, formulate the Aviary problem, and optimize.
# We'll discuss the results from each case and explain why they vary.
#
# ## Fixed Mission Profile, Fixed Aircraft Wing Aspect Ratio
#
# First, let us run Aviary with a simple setup: fly a prescribed mission profile with an unchanged wing design.
# Here we are varying the durations of each of the phases (climb, cruise, and descent) to minimize fuel burn across the mission.
# The altitude and Mach profiles of the mission are fixed because `optimize_altitude = False` and `optimize_mach = False` for each of the phases in the `phase_info` object.

# %%
from openmdao.core.problem import _clear_problem_names
_clear_problem_names()  # need to reset these to simulate separate runs
from openmdao.utils.reports_system import clear_reports
clear_reports()

# %%
import aviary.api as av

aircraft_filename = 'models/test_aircraft/aircraft_for_bench_FwFm.csv'
optimizer = "IPOPT"
make_plots = True
max_iter = 200

prob = av.run_aviary(aircraft_filename, phase_info, optimizer=optimizer,
                     make_plots=make_plots, max_iter=max_iter)
# Out:
# Unused: aircraft:crew_and_payload:num_non_flight_crew [3]
# Unused: aircraft:nacelle:count_factor [2]
#
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
# /Users/hschilli/Documents/OpenMDAO/dev/I112-level1-reports-location/aviary/subsystems/propulsion/engine_model.py:132: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/recorders/sqlite_recorder.py:227: UserWarning:The existing case recorder file, dymos_solution.db, is being overwritten.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.514647 seconds.
# Total jacobian shape: (135, 95)
#
#
# Jacobian shape: (135, 95)  (13.73% nonzero)
# FWD solves: 21   REV solves: 0
# Total colors vs. total size: 21 vs 95  (77.89% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.5146 sec
# Time to compute coloring:   0.0907 sec
# Memory to compute coloring:   0.6719 MB
# Coloring created on: 2024-02-22 09:55:39
#
# List of user-set options:
#
#                                     Name   Value                used
#                              alpha_for_y = safer-min-dual-infeas  yes
#                         file_print_level = 5                     yes
#                    hessian_approximation = limited-memory        yes
#                            linear_solver = mumps                 yes
#                                 max_iter = 200                   yes
#                                  mu_init = 1e-05                 yes
#                              mu_strategy = monotone              yes
#                       nlp_scaling_method = gradient-based        yes
#                              output_file = reports/aircraft_for_bench_FwFm/IPOPT.out  yes
#                              print_level = 5                     yes
#                       print_user_options = yes                   yes
#                                       sb = yes                   yes
#                                      tol = 1e-06                 yes
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:      828
# Number of nonzeros in inequality constraint Jacobian.:      524
# Number of nonzeros in Lagrangian Hessian.............:        0
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/core/total_jac.py:1788: DerivativesWarning:Design variables [('traj.climb_1.t_initial', inds=[0])] have no impact on the constraints or objective.
# Total number of variables............................:       95
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       95
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       92
# Total number of inequality constraints...............:       42
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       42
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.07e+01 3.55e-02  -5.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.7213900e-02 2.04e+01 1.01e+00  -5.0 9.02e+00    -  2.60e-03 1.82e-02h  1
#    2  2.1728604e-01 1.95e+01 1.06e+00  -5.0 7.62e+00    -  2.07e-02 4.41e-02h  1
#    3r 2.1728604e-01 1.95e+01 9.99e+02   1.3 0.00e+00    -  0.00e+00 2.19e-09R  9
#    4r 1.7520649e-01 3.27e-01 9.97e+02   1.3 6.73e+03    -  1.66e-03 2.89e-03f  1
#    5  2.1453742e-01 3.22e-01 3.13e+00  -5.0 2.67e+00    -  1.28e-02 1.56e-02h  1
#    6  4.1753917e-01 2.92e-01 3.05e+00  -5.0 3.14e+00    -  2.69e-02 9.33e-02h  1
#    7  5.1745668e-01 2.78e-01 2.69e+00  -5.0 2.85e+00    -  1.18e-01 4.86e-02h  1
#    8  2.5751912e+00 6.11e-04 2.48e+00  -5.0 2.71e+00    -  8.01e-02 1.00e+00h  1
#    9  2.5805078e+00 4.11e-07 1.36e-01  -5.0 9.63e-03    -  9.65e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.5543136e+00 3.13e-07 1.36e-01  -5.0 2.78e-01    -  4.62e-04 1.00e+00f  1
#   11  2.5200838e+00 2.89e-06 8.87e-02  -5.0 1.18e+00    -  6.24e-01 3.06e-01h  2
#   12  2.5072713e+00 2.58e-02 4.73e-02  -5.0 2.17e-01    -  8.24e-01 9.05e-01h  1
#   13  2.5131686e+00 9.85e-08 1.28e-02  -5.0 4.43e-02    -  7.83e-01 1.00e+00h  1
#   14  2.5130451e+00 1.99e-11 2.13e-04  -5.0 1.89e-02    -  1.00e+00 1.00e+00h  1
#   15  2.5130516e+00 4.03e-14 2.30e-08  -5.0 1.50e-04    -  1.00e+00 1.00e+00h  1
#   16  2.5130314e+00 5.73e-08 4.22e-05  -7.0 2.82e-04    -  1.00e+00 9.11e-01h  1
#   17  2.5130306e+00 2.25e-16 7.91e-08  -7.0 5.24e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 17
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.5130306129626496e+00    2.5130306129626496e+00
# Dual infeasibility......:   7.9123905324285201e-08    7.9123905324285201e-08
# Constraint violation....:   2.2457229460508297e-16    2.2457229460508297e-16
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1128399160424995e-08    9.1128399160424995e-08
# Overall NLP error.......:   9.1128399160424995e-08    9.1128399160424995e-08
#
#
# Number of objective function evaluations             = 30
# Number of objective gradient evaluations             = 18
# Number of equality constraint evaluations            = 30
# Number of inequality constraint evaluations          = 30
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 19
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT                               = 16.543
#
# EXIT: Optimal Solution Found.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                   16.5450
#        User Objective Time :      13.5721
#        User Sensitivity Time :     2.8383
#        Interface Time :            0.0703
#        Opt Solver Time:            0.0643
#     Calls to Objective Function :      31
#     Calls to Sens Function :           20
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.513031E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0            c     7.407407E-01     1.204724E+00     1.481481E+00
#           1  traj.climb_1.t_initial_0               c    -1.666667E+18     0.000000E+00     1.666667E+18
#           2  traj.climb_1.t_duration_0              c     5.000000E-01     8.028197E-01     1.500000E+00
#           3  traj.climb_1.states:mass_0             c     0.000000E+00     7.937914E+00     1.000000E+17
#           4  traj.climb_1.states:mass_1             c     0.000000E+00     7.916114E+00     1.000000E+17
#           5  traj.climb_1.states:mass_2             c     0.000000E+00     7.909733E+00     1.000000E+17
#           6  traj.climb_1.states:mass_3             c     0.000000E+00     7.882277E+00     1.000000E+17
#           7  traj.climb_1.states:mass_4             c     0.000000E+00     7.848535E+00     1.000000E+17
#           8  traj.climb_1.states:mass_5             c     0.000000E+00     7.838356E+00     1.000000E+17
#           9  traj.climb_1.states:mass_6             c     0.000000E+00     7.811412E+00     1.000000E+17
#          10  traj.climb_1.states:mass_7             c     0.000000E+00     7.774984E+00     1.000000E+17
#          11  traj.climb_1.states:mass_8             c     0.000000E+00     7.763435E+00     1.000000E+17
#          12  traj.climb_1.states:mass_9             c     0.000000E+00     7.741169E+00     1.000000E+17
#          13  traj.climb_1.states:mass_10            c     0.000000E+00     7.710195E+00     1.000000E+17
#          14  traj.climb_1.states:mass_11            c     0.000000E+00     7.700295E+00     1.000000E+17
#          83  traj.descent_1.states:distance_3       c     0.000000E+00     3.629169E+00     1.000000E+15
#          84  traj.descent_1.states:distance_4       c     0.000000E+00     3.674030E+00     1.000000E+15
#          85  traj.descent_1.states:distance_5       c     0.000000E+00     3.687429E+00     1.000000E+15
#          86  traj.descent_1.states:distance_6       c     0.000000E+00     3.721896E+00     1.000000E+15
#          87  traj.descent_1.states:distance_7       c     0.000000E+00     3.764458E+00     1.000000E+15
#          88  traj.descent_1.states:distance_8       c     0.000000E+00     3.776681E+00     1.000000E+15
#          89  traj.descent_1.states:distance_9       c     0.000000E+00     3.798485E+00     1.000000E+15
#          90  traj.descent_1.states:distance_10      c     0.000000E+00     3.824711E+00     1.000000E+15
#          91  traj.descent_1.states:distance_11      c     0.000000E+00     3.832057E+00     1.000000E+15
#          92  traj.descent_1.states:distance_12      c     0.000000E+00     3.839737E+00     1.000000E+15
#          93  traj.descent_1.states:distance_13      c     0.000000E+00     3.849355E+00     1.000000E+15
#          94  traj.descent_1.states:distance_14      c     0.000000E+00     3.852160E+00     1.000000E+15
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                      Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                           e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                            e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           2  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -7.313165E-17    0.000000E+00              9.00000E+100
#           3  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    2.128426E-17    0.000000E+00              9.00000E+100
#           4  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -3.258602E-17    0.000000E+00              9.00000E+100
#           5  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -4.679151E-17    0.000000E+00              9.00000E+100
#           6  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.175625E-16    0.000000E+00              9.00000E+100
#           7  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.282051E-16    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.632610E-16    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.340043E-16    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.587230E-16    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.223270E-16    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.416768E-16    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.245723E-16    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -5.079198E-17    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.021776E-16    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.292007E-16    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    5.347450E-18    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    4.981572E-18    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    4.249815E-18    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    8.679331E-18    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    7.184876E-18    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    6.380170E-18    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    6.150317E-18    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    6.560338E-18    0.000000E+00              9.00000E+100
#          25  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    5.056927E-18    0.000000E+00              9.00000E+100
#          26  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    2.873951E-18    0.000000E+00              9.00000E+100
#          27  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    5.632943E-18    0.000000E+00              9.00000E+100
#          28  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    2.184202E-18    0.000000E+00              9.00000E+100
#          29  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    1.350935E-18    0.000000E+00              9.00000E+100
#          30  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    2.195269E-18    0.000000E+00              9.00000E+100
#          31  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    1.294646E-18    0.000000E+00              9.00000E+100
#          32  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.191957E-17    0.000000E+00              9.00000E+100
#          33  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    5.501901E-17    0.000000E+00              9.00000E+100
#          34  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.040596E-17    0.000000E+00              9.00000E+100
#          35  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    9.420637E-17    0.000000E+00              9.00000E+100
#          36  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    8.000350E-17    0.000000E+00              9.00000E+100
#          37  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.119412E-17    0.000000E+00              9.00000E+100
#          38  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    8.485651E-17    0.000000E+00              9.00000E+100
#          39  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    9.532999E-17    0.000000E+00              9.00000E+100
#          40  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.267308E-17    0.000000E+00              9.00000E+100
#          41  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.638405E-17    0.000000E+00              9.00000E+100
#          42  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.496957E-17    0.000000E+00              9.00000E+100
#          43  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.800210E-17    0.000000E+00              9.00000E+100
#          44  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.500192E-17    0.000000E+00              9.00000E+100
#          45  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.401521E-18    0.000000E+00              9.00000E+100
#          46  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    6.223751E-17    0.000000E+00              9.00000E+100
#          47  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -1.126789E-18    0.000000E+00              9.00000E+100
#          48  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -9.014315E-19    0.000000E+00              9.00000E+100
#          49  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -4.056442E-18    0.000000E+00              9.00000E+100
#          50  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    1.380735E-18    0.000000E+00              9.00000E+100
#          51  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    9.204897E-19    0.000000E+00              9.00000E+100
#          52  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    5.062693E-18    0.000000E+00              9.00000E+100
#          53  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    1.094371E-18    0.000000E+00              9.00000E+100
#          54  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -4.924670E-18    0.000000E+00              9.00000E+100
#          55  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -1.641557E-18    0.000000E+00              9.00000E+100
#          56  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -3.221714E-18    0.000000E+00              9.00000E+100
#          57  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    4.602448E-19    0.000000E+00              9.00000E+100
#          58  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    1.380735E-18    0.000000E+00              9.00000E+100
#          59  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    4.957873E-18    0.000000E+00              9.00000E+100
#          60  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -8.338241E-18    0.000000E+00              9.00000E+100
#          61  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -6.310021E-18    0.000000E+00              9.00000E+100
#          62  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    4.513301E-17    0.000000E+00              9.00000E+100
#          63  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -1.849205E-18    0.000000E+00              9.00000E+100
#          64  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    2.472621E-17    0.000000E+00              9.00000E+100
#          65  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    2.256097E-17    0.000000E+00              9.00000E+100
#          66  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    4.003480E-17    0.000000E+00              9.00000E+100
#          67  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.860822E-17    0.000000E+00              9.00000E+100
#          68  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -4.065298E-17    0.000000E+00              9.00000E+100
#          69  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    3.497346E-17    0.000000E+00              9.00000E+100
#          70  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    4.828431E-17    0.000000E+00              9.00000E+100
#          71  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.274603E-17    0.000000E+00              9.00000E+100
#          72  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.228100E-17    0.000000E+00              9.00000E+100
#          73  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    7.595479E-18    0.000000E+00              9.00000E+100
#          74  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -7.031118E-18    0.000000E+00              9.00000E+100
#          75  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.162653E-17    0.000000E+00              9.00000E+100
#          76  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -2.293566E-17    0.000000E+00              9.00000E+100
#          77  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -1.293008E-17    0.000000E+00              9.00000E+100
#          78  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -3.073544E-18    0.000000E+00              9.00000E+100
#          79  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    9.291288E-18    0.000000E+00              9.00000E+100
#          80  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -1.298700E-18    0.000000E+00              9.00000E+100
#          81  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -7.215000E-19    0.000000E+00              9.00000E+100
#          82  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -2.164500E-18    0.000000E+00              9.00000E+100
#          83  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    3.028006E-17    0.000000E+00              9.00000E+100
#          84  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    8.577921E-20    0.000000E+00              9.00000E+100
#          85  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    1.441091E-17    0.000000E+00              9.00000E+100
#          86  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -2.922075E-18    0.000000E+00              9.00000E+100
#          87  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -2.092350E-18    0.000000E+00              9.00000E+100
#          88  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    1.601730E-17    0.000000E+00              9.00000E+100
#          89  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    4.857612E-18    0.000000E+00              9.00000E+100
#          90  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -4.221707E-18    0.000000E+00              9.00000E+100
#          91  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    6.924306E-18    0.000000E+00              9.00000E+100
#          92  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00
traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    5.736927E-02    1.000000E+00              9.00000E+100
#
#
#    Exit Status
#       Inform  Description
#            0  Solve Succeeded
# --------------------------------------------------------------------------------

# %% [markdown]
# Now that we've run the case successfully, let's save and print out the fuel burn value:

# %%
fixed_mission_fixed_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
fixed_mission_fixed_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', fixed_mission_fixed_wing_fuel_burn)
print('Aspect ratio:', fixed_mission_fixed_wing_aspect_ratio)
# Out:
# Mission fuel burn, kg: 11398.915116162809
# Aspect ratio: 11.22091

# %% [markdown]
# ## Fixed Mission Profile, Optimized Aircraft Wing Aspect Ratio
#
# Now we will use the exact same `phase_info` object but set up our Aviary problem such that the aspect ratio of the wing is a design variable.
# This means that Aviary is optimizing the wing aspect ratio while flying the same mission profile as above.
# We would expect that by varying the wing aspect ratio, Aviary could find a lower fuel burn value.
#
# ```{note}
# All of the realistic design tradeoffs associated with varying the wing aspect ratio are not necessarily captured in this problem, e.g. the wing structure would need to change. We are simply using this as an example of an aircraft design variable available in Aviary.
# ```
#
# When we want to add an aircraft design variable to the Aviary problem, we need to use the Level 2 interface for Aviary.
# This means we can no longer use the all-inclusive `run_aviary` function and instead need to call its constituent methods individually.
# This allows us to insert a line adding the wing aspect ratio as a design variable as shown below.
# This line is highlighted with an in-line comment.

# %%
from openmdao.core.problem import _clear_problem_names
_clear_problem_names()  # need to reset these to simulate separate runs
from openmdao.utils.reports_system import clear_reports
clear_reports()

# %%
prob = av.AviaryProblem(av.AnalysisScheme.COLLOCATION)

# Load aircraft and options data from user
# Allow for user overrides here
prob.load_inputs(aircraft_filename, phase_info)

prob.check_and_preprocess_inputs()

prob.add_pre_mission_systems()

prob.add_phases()

prob.add_post_mission_systems()

# Link phases and variables
prob.link_phases()

prob.add_driver(optimizer, max_iter=max_iter)

prob.add_design_variables()

# The following line is an example of how to add a design variable for the aspect ratio of the wing
prob.model.add_design_var(av.Aircraft.Wing.ASPECT_RATIO, lower=10., upper=14., ref=12.)

# Load optimization problem formulation
# Detail which variables the optimizer can control
prob.add_objective()

prob.setup()

prob.set_initial_guesses()

prob.run_aviary_problem(make_plots=make_plots)
# Out:
# Unused: aircraft:crew_and_payload:num_non_flight_crew [3]
# Unused: aircraft:nacelle:count_factor [2]
# /Users/hschilli/Documents/OpenMDAO/dev/I112-level1-reports-location/aviary/subsystems/propulsion/engine_model.py:132: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
#
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/recorders/sqlite_recorder.py:227: UserWarning:The existing case recorder file, aviary_history.db, is being overwritten.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.645547 seconds.
# Total jacobian shape: (135, 96)
#
#
# Jacobian shape: (135, 96)  (14.34% nonzero)
# FWD solves: 22   REV solves: 0
# Total colors vs. total size: 22 vs 96  (77.08% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.6455 sec
# Time to compute coloring:   0.1061 sec
# Memory to compute coloring:  -0.4453 MB
# Coloring created on: 2024-02-22 09:56:05
#
# List of user-set options:
#
#                                     Name   Value                used
#                              alpha_for_y = safer-min-dual-infeas  yes
#                         file_print_level = 5                     yes
#                    hessian_approximation = limited-memory        yes
#                            linear_solver = mumps                 yes
#                                 max_iter = 200                   yes
#                                  mu_init = 1e-05                 yes
#                              mu_strategy = monotone              yes
#                       nlp_scaling_method = gradient-based        yes
#                              output_file = reports/problem/IPOPT.out  yes
#                              print_level = 5                     yes
#                       print_user_options = yes                   yes
#                                       sb = yes                   yes
#                                      tol = 1e-06                 yes
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:      896
# Number of nonzeros in inequality constraint Jacobian.:      539
# Number of nonzeros in Lagrangian Hessian.............:        0
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/core/total_jac.py:1788: DerivativesWarning:Design variables [('traj.climb_1.t_initial', inds=[0])] have no impact on the constraints or objective.
# Total number of variables............................:       96
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       96
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       92
# Total number of inequality constraints...............:       42
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       42
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.07e+01 7.93e-02  -5.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.0509211e-02 2.04e+01 1.05e+00  -5.0 9.11e+00    -  2.60e-03 1.69e-02h  1
#    2  8.8476003e-02 1.95e+01 1.03e+00  -5.0 7.63e+00    -  1.95e-02 4.53e-02h  1
#    3r 8.8476003e-02 1.95e+01 9.99e+02   1.3 0.00e+00    -  0.00e+00 2.54e-07R  2
#    4r 4.4989389e-02 3.27e-01 9.97e+02   1.3 6.73e+03    -  2.02e-03 2.89e-03f  1
#    5  7.5256018e-02 3.22e-01 3.15e+00  -5.0 2.67e+00    -  9.96e-03 1.59e-02h  1
#    6  1.4562741e-01 3.09e-01 3.05e+00  -5.0 3.14e+00    -  2.64e-02 4.23e-02h  1
#    7  6.0335633e-01 2.37e-01 2.84e+00  -5.0 3.01e+00    -  6.86e-02 2.33e-01H  1
#    8  6.4119040e-01 2.29e-01 2.49e+00  -5.0 2.31e+00    -  1.30e-01 3.22e-02h  1
#    9  1.3235586e+00 1.31e-01 2.25e+00  -5.0 2.23e+00    -  8.61e-02 4.26e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.3355342e+00 6.13e-05 1.10e+00  -5.0 1.28e+00    -  4.42e-01 1.00e+00h  1
#   11  2.3366221e+00 4.93e-11 1.86e-02  -5.0 3.43e-03    -  9.71e-01 1.00e+00h  1
#   12  2.3089571e+00 5.53e-08 5.55e-02  -5.0 4.46e-01    -  5.23e-04 1.00e+00F  1
#   13  2.3033901e+00 1.40e-06 7.34e-03  -5.0 1.38e-01    -  9.35e-01 1.00e+00h  1
#   14  2.3025102e+00 2.93e-03 3.05e-03  -5.0 4.78e-02    -  9.91e-01 5.12e-01h  1
#   15  2.3029249e+00 1.34e-10 1.80e-03  -5.0 9.26e-03    -  1.00e+00 1.00e+00h  1
#   16  2.3029095e+00 3.34e-13 2.45e-06  -5.0 4.61e-04    -  1.00e+00 1.00e+00h  1
#   17  2.3028643e+00 3.03e-07 2.58e-05  -7.0 9.99e-04    -  1.00e+00 8.45e-01h  1
#   18  2.3028614e+00 9.90e-15 1.39e-06  -7.0 1.34e-05    -  1.00e+00 1.00e+00f  1
#   19  2.3028613e+00 2.91e-16 1.24e-09  -7.0 1.04e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 19
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.3028613407817642e+00    2.3028613407817642e+00
# Dual infeasibility......:   1.2355942935471376e-09    1.2355942935471376e-09
# Constraint violation....:   2.9103830456733706e-16    2.9103830456733706e-16
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0999344397226580e-08    9.0999344397226580e-08
# Overall NLP error.......:   9.0999344397226580e-08    9.0999344397226580e-08
#
#
# Number of objective function evaluations             = 24
# Number of objective gradient evaluations             = 20
# Number of equality constraint evaluations            = 24
# Number of inequality constraint evaluations          = 24
# Number of equality constraint Jacobian evaluations   = 21
# Number of inequality constraint Jacobian evaluations = 21
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT                               = 14.437
#
# EXIT: Optimal Solution Found.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                   14.4390
#        User Objective Time :       9.9579
#        User Sensitivity Time :     4.3283
#        Interface Time :            0.0802
#        Opt Solver Time:            0.0727
#     Calls to Objective Function :      25
#     Calls to Sens Function :           22
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.302861E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0            c     7.407407E-01     1.186031E+00     1.481481E+00
#           1  aircraft:wing:aspect_ratio_0           c     8.333333E-01     1.166667E+00     1.166667E+00          u
#           2  traj.climb_1.t_initial_0               c    -1.666667E+18     0.000000E+00     1.666667E+18
#           3  traj.climb_1.t_duration_0              c     5.000000E-01     6.465533E-01     1.500000E+00
#           4  traj.climb_1.states:mass_0             c     0.000000E+00     7.943528E+00     1.000000E+17
#           5  traj.climb_1.states:mass_1             c     0.000000E+00     7.927995E+00     1.000000E+17
#           6  traj.climb_1.states:mass_2             c     0.000000E+00     7.923353E+00     1.000000E+17
#           7  traj.climb_1.states:mass_3             c     0.000000E+00     7.902902E+00     1.000000E+17
#           8  traj.climb_1.states:mass_4             c     0.000000E+00     7.876832E+00     1.000000E+17
#          78  traj.descent_1.states:mass_12          c     0.000000E+00     6.915510E+00     1.000000E+17
#          79  traj.descent_1.states:mass_13          c     0.000000E+00     6.912473E+00     1.000000E+17
#          80  traj.descent_1.states:mass_14          c     0.000000E+00     6.911450E+00     1.000000E+17
#          81  traj.descent_1.states:distance_0       c     0.000000E+00     3.481035E+00     1.000000E+15
#          82  traj.descent_1.states:distance_1       c     0.000000E+00     3.512810E+00     1.000000E+15
#          83  traj.descent_1.states:distance_2       c     0.000000E+00     3.522643E+00     1.000000E+15
#          84  traj.descent_1.states:distance_3       c     0.000000E+00     3.567157E+00     1.000000E+15
#          85  traj.descent_1.states:distance_4       c     0.000000E+00     3.624485E+00     1.000000E+15
#          86  traj.descent_1.states:distance_5       c     0.000000E+00     3.641608E+00     1.000000E+15
#          87  traj.descent_1.states:distance_6       c     0.000000E+00     3.685654E+00     1.000000E+15
#          88  traj.descent_1.states:distance_7       c     0.000000E+00     3.740048E+00     1.000000E+15
#          89  traj.descent_1.states:distance_8       c     0.000000E+00     3.755671E+00     1.000000E+15
#          90  traj.descent_1.states:distance_9       c     0.000000E+00     3.783538E+00     1.000000E+15
#          91  traj.descent_1.states:distance_10      c     0.000000E+00     3.817063E+00     1.000000E+15
#          92  traj.descent_1.states:distance_11      c     0.000000E+00     3.826454E+00     1.000000E+15
#          93  traj.descent_1.states:distance_12      c     0.000000E+00     3.836273E+00     1.000000E+15
#          94  traj.descent_1.states:distance_13      c     0.000000E+00     3.848572E+00     1.000000E+15
#          95  traj.descent_1.states:distance_14      c     0.000000E+00     3.852160E+00     1.000000E+15
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                      Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                           e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                            e   0.000000E+00    2.910383E-16    0.000000E+00              9.00000E+100
#           2  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.444973E-17    0.000000E+00              9.00000E+100
#           3  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -9.633151E-18    0.000000E+00              9.00000E+100
#           4  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    2.689845E-17    0.000000E+00              9.00000E+100
#           5  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -8.068359E-17    0.000000E+00              9.00000E+100
#           6  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.128341E-17    0.000000E+00              9.00000E+100
#           7  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    1.992679E-17    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    4.028756E-17    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.289890E-18    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    3.568695E-18    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -3.822616E-17    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -6.003351E-18    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    1.121108E-17    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    4.480123E-18    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.202373E-17    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.347579E-17    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00   -1.133312E-19    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    2.266624E-20    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    2.314545E-19    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00   -3.240363E-19    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    1.045671E-18    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00   -6.604236E-19    0.000000E+00              9.00000E+100
#          25  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00   -3.302118E-19    0.000000E+00              9.00000E+100
#          26  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00   -3.703272E-19    0.000000E+00              9.00000E+100
#          27  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    8.332362E-19    0.000000E+00              9.00000E+100
#          28  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00   -9.258180E-20    0.000000E+00              9.00000E+100
#          29  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    3.173273E-19    0.000000E+00              9.00000E+100
#          30  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    1.405307E-18    0.000000E+00              9.00000E+100
#          31  traj.climb_1.collocation_constraint.defects:distance         e   0.000000E+00    7.253196E-19    0.000000E+00              9.00000E+100
#          32  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    3.717922E-17    0.000000E+00              9.00000E+100
#          33  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -1.271688E-17    0.000000E+00              9.00000E+100
#          34  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -7.064934E-19    0.000000E+00              9.00000E+100
#          35  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    6.492872E-18    0.000000E+00              9.00000E+100
#          36  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    1.442860E-18    0.000000E+00              9.00000E+100
#          37  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.110183E-17    0.000000E+00              9.00000E+100
#          38  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    1.350892E-17    0.000000E+00              9.00000E+100
#          39  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    9.220373E-18    0.000000E+00              9.00000E+100
#          40  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -1.115022E-17    0.000000E+00              9.00000E+100
#          41  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -1.424825E-17    0.000000E+00              9.00000E+100
#          42  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -8.296447E-18    0.000000E+00              9.00000E+100
#          43  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -2.110183E-17    0.000000E+00              9.00000E+100
#          44  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.561039E-17    0.000000E+00              9.00000E+100
#          45  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    5.651947E-18    0.000000E+00              9.00000E+100
#          46  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -2.472727E-18    0.000000E+00              9.00000E+100
#          47  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    9.043116E-19    0.000000E+00              9.00000E+100
#          48  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -1.582545E-18    0.000000E+00              9.00000E+100
#          49  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    5.878025E-18    0.000000E+00              9.00000E+100
#          50  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    5.540584E-18    0.000000E+00              9.00000E+100
#          51  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -1.385146E-18    0.000000E+00              9.00000E+100
#          52  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -2.308577E-18    0.000000E+00              9.00000E+100
#          53  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    3.293603E-18    0.000000E+00              9.00000E+100
#          54  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    4.391471E-18    0.000000E+00              9.00000E+100
#          55  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    7.136140E-18    0.000000E+00              9.00000E+100
#          56  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -6.925730E-18    0.000000E+00              9.00000E+100
#          57  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    1.061945E-17    0.000000E+00              9.00000E+100
#          58  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00   -1.292803E-17    0.000000E+00              9.00000E+100
#          59  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    2.125132E-17    0.000000E+00              9.00000E+100
#          60  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    1.808623E-18    0.000000E+00              9.00000E+100
#          61  traj.cruise.collocation_constraint.defects:distance          e   0.000000E+00    6.330181E-18    0.000000E+00              9.00000E+100
#          62  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -2.334480E-17    0.000000E+00              9.00000E+100
#          63  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.076435E-17    0.000000E+00              9.00000E+100
#          64  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.910430E-17    0.000000E+00              9.00000E+100
#          65  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -2.817751E-17    0.000000E+00              9.00000E+100
#          66  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -4.825287E-18    0.000000E+00              9.00000E+100
#          67  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -1.859896E-17    0.000000E+00              9.00000E+100
#          68  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -5.491691E-17    0.000000E+00              9.00000E+100
#          69  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.899776E-17    0.000000E+00              9.00000E+100
#          70  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    3.116703E-17    0.000000E+00              9.00000E+100
#          71  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -6.296279E-17    0.000000E+00              9.00000E+100
#          72  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    5.032342E-18    0.000000E+00              9.00000E+100
#          73  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -3.420912E-19    0.000000E+00              9.00000E+100
#          74  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    6.766289E-18    0.000000E+00              9.00000E+100
#          75  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -1.518999E-17    0.000000E+00              9.00000E+100
#          76  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.186635E-17    0.000000E+00              9.00000E+100
#          77  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -1.155532E-17    0.000000E+00              9.00000E+100
#          78  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    4.874902E-18    0.000000E+00              9.00000E+100
#          79  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -1.263863E-18    0.000000E+00              9.00000E+100
#          80  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -4.609229E-18    0.000000E+00              9.00000E+100
#          81  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -6.452921E-18    0.000000E+00              9.00000E+100
#          82  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    6.729475E-18    0.000000E+00              9.00000E+100
#          83  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -1.643975E-17    0.000000E+00              9.00000E+100
#          84  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00   -2.191967E-19    0.000000E+00              9.00000E+100
#          85  traj.descent_1.collocation_constraint.defects:distance       e   0.000000E+00    1.753574E-18    0.000000E+00              9.00000E+100
traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.841016E-03    1.000000E+00              9.00000E+100
#         129  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.506090E-04    1.000000E+00              9.00000E+100
#         130  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.506090E-04    1.000000E+00              9.00000E+100
#         131  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.004515E-06    1.000000E+00              9.00000E+100
#         132  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    8.451559E-03    1.000000E+00              9.00000E+100
#         133  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.377076E-02    1.000000E+00              9.00000E+100
#
#
#    Exit Status
#       Inform  Description
#            0  Solve Succeeded
# --------------------------------------------------------------------------------
# False

# %%
fixed_mission_optimized_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
fixed_mission_optimized_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', fixed_mission_optimized_wing_fuel_burn)
print('Aspect ratio:', fixed_mission_optimized_wing_aspect_ratio)
# Out:
# Mission fuel burn, kg: 10445.60333346578
# Aspect ratio: 13.99999830092345

# %% [markdown]
# As expected, the optimal fuel burn value is lower for this case.
# We'll discuss this in more detail after running two more cases.
#
# ## Optimized Mission Profile, Fixed Aircraft Wing Aspect Ratio
#
# We just investigated giving the optimizer flexibility with the aircraft design while not varying the mission.
# Let's now look at the results when we optimize the mission but keep the wing aspect ratio unchanged.
#
# To do this, we will allow the optimizer to control the Mach and altitude profiles by modifying the `phase_info` object:

# %%
from openmdao.core.problem import _clear_problem_names
_clear_problem_names()  # need to reset these to simulate separate runs
from openmdao.utils.reports_system import clear_reports
clear_reports()

# %%
phase_info['climb_1']['user_options']['optimize_mach'] = True
phase_info['climb_1']['user_options']['optimize_altitude'] = True
phase_info['cruise']['user_options']['optimize_mach'] = True
phase_info['cruise']['user_options']['optimize_altitude'] = True
phase_info['descent_1']['user_options']['optimize_mach'] = True
phase_info['descent_1']['user_options']['optimize_altitude'] = True

prob = av.run_aviary(aircraft_filename, phase_info, optimizer=optimizer,
                     make_plots=make_plots, max_iter=max_iter)
# Out:
# Unused: aircraft:crew_and_payload:num_non_flight_crew [3]
# Unused: aircraft:nacelle:count_factor [2]
#
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
# /Users/hschilli/Documents/OpenMDAO/dev/I112-level1-reports-location/aviary/subsystems/propulsion/engine_model.py:132: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [initial] 2.0000e-01 == mach [unitless]
#         [initial] 0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [final]   2.1000e-01 == mach [unitless]
#         [final]   0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/recorders/sqlite_recorder.py:227: UserWarning:The existing case recorder file, dymos_solution.db, is being overwritten.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.666489 seconds.
# Total jacobian shape: (143, 107)
#
#
# Jacobian shape: (143, 107)  (13.89% nonzero)
# FWD solves: 25   REV solves: 0
# Total colors vs. total size: 25 vs 107  (76.64% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.6665 sec
# Time to compute coloring:   0.0987 sec
# Memory to compute coloring:   0.0586 MB
# Coloring created on: 2024-02-22 09:56:29
#
# List of user-set options:
#
#                                     Name   Value                used
#                              alpha_for_y = safer-min-dual-infeas  yes
#                         file_print_level = 5                     yes
#                    hessian_approximation = limited-memory        yes
#                            linear_solver = mumps                 yes
#                                 max_iter = 200                   yes
#                                  mu_init = 1e-05                 yes
#                              mu_strategy = monotone              yes
#                       nlp_scaling_method = gradient-based        yes
#                              output_file = reports/aircraft_for_bench_FwFm/IPOPT.out  yes
#                              print_level = 5                     yes
#                       print_user_options = yes                   yes
#                                       sb = yes                   yes
#                                      tol = 1e-06                 yes
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:     1031
# Number of nonzeros in inequality constraint Jacobian.:      731
# Number of nonzeros in Lagrangian Hessian.............:        0
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/core/total_jac.py:1788: DerivativesWarning:Design variables [('traj.climb_1.t_initial', inds=[0])] have no impact on the constraints or objective.
# Total number of variables............................:      107
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      107
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      100
# Total number of inequality constraints...............:       42
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       42
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.07e+01 8.41e-02  -5.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.8482967e-02 2.04e+01 1.02e+00  -5.0 9.05e+00    -  2.60e-03 1.67e-02h  1
#    2  2.2227422e-01 1.94e+01 1.06e+00  -5.0 7.05e+00    -  1.89e-02 4.95e-02h  1
#    3  2.3023732e-01 1.94e+01 1.06e+00  -5.0 8.23e+00    -  3.98e-04 1.47e-03h  1
#    4  2.5418935e-01 1.93e+01 1.84e+00  -5.0 7.80e+00    -  5.61e-04 4.11e-03h  1
#    5  2.5481058e-01 1.93e+01 1.85e+00  -5.0 1.60e+01    -  1.72e-04 1.71e-04h  1
#    6  2.6421474e-01 1.92e+01 1.66e+00  -5.0 1.08e+01    -  2.27e-04 3.55e-03h  1
#    7  2.6607843e-01 1.92e+01 1.65e+00  -5.0 8.92e+00    -  4.46e-04 5.25e-04h  1
#    8  2.8513253e-01 1.91e+01 1.53e+00  -5.0 5.86e+00    -  7.09e-04 6.11e-03h  1
#    9  2.8544397e-01 1.91e+01 1.53e+00  -5.0 8.64e+00    -  8.34e-05 5.03e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                   29.3178
#        User Objective Time :      22.0626
#        User Sensitivity Time :     6.9364
#        Interface Time :            0.1595
#        Opt Solver Time:            0.1594
#     Calls to Objective Function :      46
#     Calls to Sens Function :           39
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.481432E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                            Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0                        c     7.407407E-01     1.202163E+00     1.481481E+00
#           1  traj.climb_1.t_initial_0                           c    -1.666667E+18     0.000000E+00     1.666667E+18
#           2  traj.climb_1.t_duration_0                          c     5.000000E-01     7.305299E-01     1.500000E+00
#           3  traj.climb_1.states:mass_0                         c     0.000000E+00     7.939181E+00     1.000000E+17
#           4  traj.climb_1.states:mass_1                         c     0.000000E+00     7.919050E+00     1.000000E+17
#           5  traj.climb_1.states:mass_2                         c     0.000000E+00     7.913174E+00     1.000000E+17
#           6  traj.climb_1.states:mass_3                         c     0.000000E+00     7.887923E+00     1.000000E+17
#           7  traj.climb_1.states:mass_4                         c     0.000000E+00     7.856819E+00     1.000000E+17
#           8  traj.climb_1.states:mass_5                         c     0.000000E+00     7.847380E+00     1.000000E+17
#           9  traj.climb_1.states:mass_6                         c     0.000000E+00     7.822227E+00     1.000000E+17
#          10  traj.climb_1.states:mass_7                         c     0.000000E+00     7.787830E+00     1.000000E+17
#          11  traj.climb_1.states:mass_8                         c     0.000000E+00     7.776846E+00     1.000000E+17
#          12  traj.climb_1.states:mass_9                         c     0.000000E+00     7.755621E+00     1.000000E+17
#          13  traj.climb_1.states:mass_10                        c     0.000000E+00     7.725976E+00     1.000000E+17
#          14  traj.climb_1.states:mass_11                        c     0.000000E+00     7.716488E+00     1.000000E+17
#          15  traj.climb_1.states:mass_12                        c     0.000000E+00     7.705792E+00     1.000000E+17
#          16  traj.climb_1.states:mass_13                        c     0.000000E+00     7.690893E+00     1.000000E+17
#          17  traj.climb_1.states:mass_14                        c     0.000000E+00     7.686138E+00     1.000000E+17
#          18  traj.climb_1.states:distance_0                     c     0.000000E+00     9.182937E-03     1.000000E+15
#          19  traj.climb_1.states:distance_1                     c     0.000000E+00     2.342236E-02     1.000000E+15
#          20  traj.climb_1.states:distance_2                     c     0.000000E+00     2.830483E-02     1.000000E+15
#          21  traj.climb_1.states:distance_3                     c     0.000000E+00     5.350471E-02     1.000000E+15
#          22  traj.climb_1.states:distance_4                     c     0.000000E+00     9.455832E-02     1.000000E+15
#          23  traj.climb_1.states:distance_5                     c     0.000000E+00     1.090383E-01     1.000000E+15
#          24  traj.climb_1.states:distance_6                     c     0.000000E+00     1.519984E-01     1.000000E+15
#          25  traj.climb_1.states:distance_7                     c     0.000000E+00     2.195535E-01     1.000000E+15
#          26  traj.climb_1.states:distance_8                     c     0.000000E+00     2.428798E-01     1.000000E+15
#          93  traj.descent_1.states:distance_5                   c     0.000000E+00     3.677000E+00     1.000000E+15
#          94  traj.descent_1.states:distance_6                   c     0.000000E+00     3.714040E+00     1.000000E+15
#          95  traj.descent_1.states:distance_7                   c     0.000000E+00     3.759609E+00     1.000000E+15
#          96  traj.descent_1.states:distance_8                   c     0.000000E+00     3.772648E+00     1.000000E+15
#          97  traj.descent_1.states:distance_9                   c     0.000000E+00     3.795833E+00     1.000000E+15
#          98  traj.descent_1.states:distance_10                  c     0.000000E+00     3.823540E+00     1.000000E+15
#          99  traj.descent_1.states:distance_11                  c     0.000000E+00     3.831250E+00     1.000000E+15
#         100  traj.descent_1.states:distance_12                  c     0.000000E+00     3.839276E+00     1.000000E+15
#         101  traj.descent_1.states:distance_13                  c     0.000000E+00     3.849264E+00     1.000000E+15
#         102  traj.descent_1.states:distance_14                  c     0.000000E+00     3.852160E+00     1.000000E+15
#         103  traj.descent_1.polynomial_controls:mach_0          c     3.800000E-01     1.516015E+00     1.680000E+00
#         104  traj.descent_1.polynomial_controls:mach_1          c     3.800000E-01     4.200000E-01     1.680000E+00
#         105  traj.descent_1.polynomial_controls:altitude_0      c     0.000000E+00     9.999993E-01     1.000000E+00          u
#         106  traj.descent_1.polynomial_controls:altitude_1      c     0.000000E+00     0.000000E+00     1.000000E+00          l
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                           Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                                e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                                 e   0.000000E+00   -2.910383E-16    0.000000E+00              9.00000E+100
#           2  traj.linkages.climb_1:altitude_final|cruise:altitude_initial      e   0.000000E+00    3.637979E-16    0.000000E+00              9.00000E+100
#           3  traj.linkages.climb_1:mach_final|cruise:mach_initial              e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           4  traj.linkages.cruise:altitude_final|descent_1:altitude_initial    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           5  traj.linkages.cruise:mach_final|descent_1:mach_initial            e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           6  traj.phases.climb_1->initial_boundary_constraint->mach            e   2.000000E-01    2.000000E-01    2.000000E-01              9.00000E+100
#           7  traj.phases.climb_1->initial_boundary_constraint->altitude        e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00    6.602632E-18    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -6.465097E-15    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.155803E-14    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -5.756349E-14    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.459556E-13    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -3.610884E-13    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -5.505564E-13    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -9.485886E-13    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.738533E-12    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.697698E-12    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.195027E-12    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -3.105911E-12    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.652021E-12    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.917607E-12    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.147886E-12    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    2.304919E-19    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+
traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.879326E-01    1.000000E+00              9.00000E+100
#         123  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.540479E-01    1.000000E+00              9.00000E+100
#         124  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.116875E-01    1.000000E+00              9.00000E+100
#         125  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.996672E-01    1.000000E+00              9.00000E+100
#         126  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.996672E-01    1.000000E+00              9.00000E+100
#         127  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.488847E-01    1.000000E+00              9.00000E+100
#         128  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.828670E-01    1.000000E+00              9.00000E+100
#         129  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.643163E-01    1.000000E+00              9.00000E+100
#         130  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.643163E-01    1.000000E+00              9.00000E+100
#         131  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.229424E-01    1.000000E+00              9.00000E+100
#         132  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    6.315595E-02    1.000000E+00              9.00000E+100
#         133  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.249374E-02    1.000000E+00              9.00000E+100
#         134  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.249374E-02    1.000000E+00              9.00000E+100
#         135  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.320404E-02    1.000000E+00              9.00000E+100
#         136  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.220757E-06    1.000000E+00              9.00000E+100
#         137  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.530569E-03    1.000000E+00              9.00000E+100
#         138  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.530569E-03    1.000000E+00              9.00000E+100
#         139  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.630389E-02    1.000000E+00              9.00000E+100
#         140  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.787200E-02    1.000000E+00              9.00000E+100
#         141  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    6.279606E-02    1.000000E+00              9.00000E+100
#
#
#    Exit Status
#       Inform  Description
#            0  Solve Succeeded
# --------------------------------------------------------------------------------
#
#
# Number of Iterations....: 36
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.4814319045015378e+00    2.4814319045015378e+00
# Dual infeasibility......:   5.8778198818253443e-07    5.8778198818253443e-07
# Constraint violation....:   2.2353747902466282e-11    2.2353747902466282e-11
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909091662386749e-08    9.0909091662386749e-08
# Overall NLP error.......:   5.8778198818253443e-07    5.8778198818253443e-07
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 37
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 45
# Number of equality constraint Jacobian evaluations   = 38
# Number of inequality constraint Jacobian evaluations = 38
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT                               = 29.316
#
# EXIT: Optimal Solution Found.

# %%
from openmdao.core.problem import _clear_problem_names
_clear_problem_names()  # need to reset these to simulate separate runs
from openmdao.utils.reports_system import clear_reports
clear_reports()

# %%
phase_info['climb_1']['user_options']['optimize_mach'] = True
phase_info['climb_1']['user_options']['optimize_altitude'] = True
phase_info['cruise']['user_options']['optimize_mach'] = True
phase_info['cruise']['user_options']['optimize_altitude'] = True
phase_info['descent_1']['user_options']['optimize_mach'] = True
phase_info['descent_1']['user_options']['optimize_altitude'] = True

prob = av.run_aviary(aircraft_filename, phase_info, optimizer=optimizer,
                     make_plots=make_plots, max_iter=max_iter)
# Out:
# Unused: aircraft:crew_and_payload:num_non_flight_crew [3]
# Unused: aircraft:nacelle:count_factor [2]
# /Users/hschilli/Documents/OpenMDAO/dev/I112-level1-reports-location/aviary/subsystems/propulsion/engine_model.py:132: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
#
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [initial] 2.0000e-01 == mach [unitless]
#         [initial] 0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [final]   2.1000e-01 == mach [unitless]
#         [final]   0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/recorders/sqlite_recorder.py:227: UserWarning:The existing case recorder file, dymos_solution.db, is being overwritten.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.654934 seconds.
# Total jacobian shape: (143, 107)
#
#
# Jacobian shape: (143, 107)  (13.89% nonzero)
# FWD solves: 25   REV solves: 0
# Total colors vs. total size: 25 vs 107  (76.64% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.6549 sec
# Time to compute coloring:   0.0999 sec
# Memory to compute coloring:  -0.2500 MB
# Coloring created on: 2024-02-22 09:57:08
#
# List of user-set options:
#
#                                     Name   Value                used
#                              alpha_for_y = safer-min-dual-infeas  yes
#                         file_print_level = 5                     yes
#                    hessian_approximation = limited-memory        yes
#                            linear_solver = mumps                 yes
#                                 max_iter = 200                   yes
#                                  mu_init = 1e-05                 yes
#                              mu_strategy = monotone              yes
#                       nlp_scaling_method = gradient-based        yes
#                              output_file = reports/aircraft_for_bench_FwFm/IPOPT.out  yes
#                              print_level = 5                     yes
#                       print_user_options = yes                   yes
#                                       sb = yes                   yes
#                                      tol = 1e-06                 yes
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:     1031
# Number of nonzeros in inequality constraint Jacobian.:      731
# Number of nonzeros in Lagrangian Hessian.............:        0
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/core/total_jac.py:1788: DerivativesWarning:Design variables [('traj.climb_1.t_initial', inds=[0])] have no impact on the constraints or objective.
# Total number of variables............................:      107
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      107
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      100
# Total number of inequality constraints...............:       42
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       42
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.07e+01 8.41e-02  -5.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5
-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.4815148e+00 5.79e-08 4.01e-03  -5.0 4.24e-03    -  1.00e+00 1.00e+00h  1
#   31  2.4814580e+00 1.57e-08 1.80e-04  -5.0 8.54e-04    -  1.00e+00 1.00e+00h  1
#   32  2.4814798e+00 7.86e-10 2.20e-05  -5.0 5.04e-05    -  1.00e+00 1.00e+00h  1
#   33  2.4814319e+00 3.69e-09 1.45e-04  -7.0 2.50e-04    -  1.00e+00 9.21e-01h  1
#   34  2.4814321e+00 1.99e-09 3.95e-05  -7.0 2.06e-05    -  1.00e+00 5.00e-01h  2
#   35  2.4814322e+00 3.00e-10 5.61e-06  -7.0 1.25e-05    -  1.00e+00 1.00e+00h  1
#   36  2.4814319e+00 2.24e-11 5.88e-07  -7.0 9.43e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 36
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.4814319045015378e+00    2.4814319045015378e+00
# Dual infeasibility......:   5.8778198818253443e-07    5.8778198818253443e-07
# Constraint violation....:   2.2353747902466282e-11    2.2353747902466282e-11
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909091662386749e-08    9.0909091662386749e-08
# Overall NLP error.......:   5.8778198818253443e-07    5.8778198818253443e-07
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 37
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 45
# Number of equality constraint Jacobian evaluations   = 38
# Number of inequality constraint Jacobian evaluations = 38
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT                               = 28.814
#
# EXIT: Optimal Solution Found.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                   28.8154
#        User Objective Time :      21.7904
#        User Sensitivity Time :     6.7057
#        Interface Time :            0.1584
#        Opt Solver Time:            0.1609
#     Calls to Objective Function :      46
#     Calls to Sens Function :           39
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.481432E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                            Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0                        c     7.407407E-01     1.202163E+00     1.481481E+00
#           1  traj.climb_1.t_initial_0                           c    -1.666667E+18     0.000000E+00     1.666667E+18
#           2  traj.climb_1.t_duration_0                          c     5.000000E-01     7.305299E-01     1.500000E+00
#           3  traj.climb_1.states:mass_0                         c     0.000000E+00     7.939181E+00     1.000000E+17
#           4  traj.climb_1.states:mass_1                         c     0.000000E+00     7.919050E+00     1.000000E+17
#           5  traj.climb_1.states:mass_2                         c     0.000000E+00     7.913174E+00     1.000000E+17
#           6  traj.climb_1.states:mass_3                         c     0.000000E+00     7.887923E+00     1.000000E+17
#           7  traj.climb_1.states:mass_4                         c     0.000000E+00     7.856819E+00     1.000000E+17
#           8  traj.climb_1.states:mass_5                         c     0.000000E+00     7.847380E+00     1.000000E+17
#           9  traj.climb_1.states:mass_6                         c     0.000000E+00     7.822227E+00     1.000000E+17
#          10  traj.climb_1.states:mass_7                         c     0.000000E+00     7.787830E+00     1.000000E+17
#          11  traj.climb_1.states:mass_8                         c     0.000000E+00     7.776846E+00     1.000000E+17
#          12  traj.climb_1.states:mass_9                         c     0.000000E+00     7.755621E+00     1.000000E+17
#          13  traj.climb_1.states:mass_10                        c     0.000000E+00     7.725976E+00     1.000000E+17
#          80  traj.descent_1.states:mass_7                       c     0.000000E+00     6.845240E+00     1.000000E+17
#          81  traj.descent_1.states:mass_8                       c     0.000000E+00     6.843781E+00     1.000000E+17
#          82  traj.descent_1.states:mass_9                       c     0.000000E+00     6.840994E+00     1.000000E+17
#          83  traj.descent_1.states:mass_10                      c     0.000000E+00     6.836975E+00     1.000000E+17
#          84  traj.descent_1.states:mass_11                      c     0.000000E+00     6.835570E+00     1.000000E+17
#          85  traj.descent_1.states:mass_12                      c     0.000000E+00     6.833891E+00     1.000000E+17
#          86  traj.descent_1.states:mass_13                      c     0.000000E+00     6.831332E+00     1.000000E+17
#          87  traj.descent_1.states:mass_14                      c     0.000000E+00     6.830452E+00     1.000000E+17
#          88  traj.descent_1.states:distance_0                   c     0.000000E+00     3.541364E+00     1.000000E+15
#          89  traj.descent_1.states:distance_1                   c     0.000000E+00     3.568254E+00     1.000000E+15
#          90  traj.descent_1.states:distance_2                   c     0.000000E+00     3.576574E+00     1.000000E+15
#          91  traj.descent_1.states:distance_3                   c     0.000000E+00     3.614203E+00     1.000000E+15
#          92  traj.descent_1.states:distance_4                   c     0.000000E+00     3.662576E+00     1.000000E+15
#          93  traj.descent_1.states:distance_5                   c     0.000000E+00     3.677000E+00     1.000000E+15
#          94  traj.descent_1.states:distance_6                   c     0.000000E+00     3.714040E+00     1.000000E+15
#          95  traj.descent_1.states:distance_7                   c     0.000000E+00     3.759609E+00     1.000000E+15
#          96  traj.descent_1.states:distance_8                   c     0.000000E+00     3.772648E+00     1.000000E+15
#          97  traj.descent_1.states:distance_9                   c     0.000000E+00     3.795833E+00     1.000000E+15
#          98  traj.descent_1.states:distance_10                  c     0.000000E+00     3.823540E+00     1.000000E+15
#          99  traj.descent_1.states:distance_11                  c     0.000000E+00     3.831250E+00     1.000000E+15
#         100  traj.descent_1.states:distance_12                  c     0.000000E+00     3.839276E+00     1.000000E+15
#         101  traj.descent_1.states:distance_13                  c     0.000000E+00     3.849264E+00     1.000000E+15
#         102  traj.descent_1.states:distance_14                  c     0.000000E+00     3.852160E+00     1.000000E+15
#         103  traj.descent_1.polynomial_controls:mach_0          c     3.800000E-01     1.516015E+00     1.680000E+00
#         104  traj.descent_1.polynomial_controls:mach_1          c     3.800000E-01     4.200000E-01     1.680000E+00
#         105  traj.descent_1.polynomial_controls:altitude_0      c     0.000000E+00     9.999993E-01     1.000000E+00          u
#         106  traj.descent_1.polynomial_controls:altitude_1      c     0.000000E+00     0.000000E+00     1.000000E+00          l
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                           Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                                e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                                 e   0.000000E+00   -2.910383E-16    0.000000E+00              9.00000E+100
#           2  traj.linkages.climb_1:altitude_final|cruise:altitude_initial      e   0.000000E+00    3.637979E-16    0.000000E+00              9.00000E+100
#           3  traj.linkages.climb_1:mach_final|cruise:mach_initial              e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           4  traj.linkages.cruise:altitude_final|descent_1:altitude_initial    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           5  traj.linkages.cruise:mach_final|descent_1:mach_initial            e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           6  traj.phases.climb_1->initial_boundary_constraint->mach            e   2.000000E-01    2.000000E-01    2.000000E-01              9.00000E+100
#           7  traj.phases.climb_1->initial_boundary_constraint->altitude        e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00    6.602632E-18    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -6.465097E-15    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.155803E-14    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -5.756349E-14    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.459556E-13    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -3.610884E-13    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -5.505564E-13    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -9.485886E-13    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.738533E-12    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.697698E-12    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.195027E-12    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -3.105911E-12    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.652021E-12    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.917607E-12    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.147886E-12    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    2.304919E-19    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    7.529401E-18    0.000000E+00              9.00000E+100
#          25  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.795276E-17    0.000000E+00              9.00000E+100
#          26  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    4.288873E-17    0.000000E+00              9.00000E+100
#          27  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    7.322466E-17    0.000000E+00              9.00000E+100
#          28  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.148058E-16    0.000000E+00              9.00000E+100
#          29  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.512302E-16    0.000000E+00              9.00000E+100
#          30  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.915251E-16    0.000000E+00              9.00000E+100
#          31  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    2.455004E-16    0.000000E+00              9.00000E+100
#          32  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    2.208246E-16    0.000000E+00              9.00000E+100
#          33  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    2.473947E-16    0.000000E+00              9.00000E+100
#          34  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    2.817057E-16    0.000000E+00              9.00000E+100
#          35  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.424952E-16    0.000000E+00              9.00000E+100
#          36  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.484880E-16    0.000000E+00              9.00000E+100
#          37  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    1.566320E-16    0.000000E+00              9.00000E+100
#          38  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -9.206363E-12    0.000000E+00              9.00000E+100
#          39  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -9.210120E-12    0.000000E+00              9.00000E+100
#          40  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -9.213517E-12    0.000000E+00              9.00000E+100
#          41  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.881806E-11    0.000000E+00              9.00000E+100
#          42  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.881981E-11    0.000000E+00              9.00000E+100
#          43  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.880880E-11    0.000000E+00              9.00000E+100
#          44  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -2.235375E-11    0.000000E+00              9.00000E+100
#          45  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -2.232293E-11    0.000000E+00              9.00000E+100
#          46  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -2.225849E-11    0.000000E+00              9.00000E+100
#          47  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.870035E-11    0.000000E+00              9.00000E+100
#          48  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.867692E-11    0.000000E+00              9.00000E+100
#          49  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.864702E-11    0.000000E+00              9.00000E+100
#          50  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -9.124570E-12    0.000000E+00              9.00000E+100
#          51  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -9.115067E-12    0.000000E+00              9.00000E+100
#          52  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -9.103311E-12    0.000000E+00              9.00000E+100
#          53  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    5.550222E-16    0.000000E+00              9.00000E+100
#          54  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    5.604680E-16    0.000000E+00              9.00000E+100
#          55  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    5.659138E-16    0.000000E+00              9.00000E+100
#          56  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.155757E-15    0.000000E+00              9.00000E+100
#          57  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.181708E-15    0.000000E+00              9.00000E+100
#          58  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.195611E-15    0.000000E+00              9.00000E+100
#          59  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.454520E-15    0.000000E+00              9.00000E+100
#          60  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.456173E-15    0.000000E+00              9.00000E+100
#          61  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.505208E-15    0.000000E+00              9.00000E+100
#          62  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.269757E-15    0.000000E+00              9.00000E+100
#          63  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.288294E-15    0.000000E+00              9.00000E+100
#          64  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.311464E-15    0.000000E+00              9.00000E+100
#          65  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    6.455593E-16    0.000000E+00              9.00000E+100
#          66  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    6.426095E-16    0.000000E+00              9.00000E+100
#          67  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    6.691580E-16    0.000000E+00              9.00000E+100
#          68  traj.phases.descent_1->final_boundary_constraint->mach            e   2.100000E-01    2.100000E-01    2.100000E-01              9.00000E+100
#          69  traj.phases.descent_1->final_boundary_constraint->altitude        e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          70  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.333474E-12    0.000000E+00              9.00000E+100
#          71  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.184973E-12    0.000000E+00              9.00000E+100
#          72  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.079515E-12    0.000000E+00              9.00000E+100
#          73  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -2.135097E-12    0.000000E+00              9.00000E+100
#          74  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.805958E-12    0.000000E+00              9.00000E+100
#          75  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.279632E-12    0.000000E+00              9.00000E+100
#          76  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.365604E-12    0.000000E+00              9.00000E+100
#          77  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.000683E-12    0.000000E+00              9.00000E+100
#          78  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -4.791028E-13    0.000000E+00              9.00000E+100
#          79  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -2.814374E-13    0.000000E+00              9.00000E+100
#          80  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.295163E-13    0.000000E+00              9.00000E+100
#          81  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -3.162558E-14    0.000000E+00              9.00000E+100
#          82  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -8.731401E-15    0.000000E+00              9.00000E+100
#          83  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -3.875908E-15    0.000000E+00              9.00000E+100
#          84  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -6.043286E-16    0.000000E+00              9.00000E+100
#          85  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -5.788993E-17    0.000000E+00              9.00000E+100
#          86  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -2.657840E-17    0.000000E+00              9.00000E+100
#          87  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -4.514686E-17    0.000000E+00              9.00000E+100
#          88  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -9.287194E-17    0.000000E+00              9.00000E+100
#          89  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -5.837028E-17    0.000000E+00              9.00000E+100
#          90  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -5.093457E-17    0.000000E+00              9.00000E+100
#          91  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -6.833565E-17    0.000000E+00              9.00000E+100
#          92  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -6.700960E-17    0.000000E+00              9.00000E+100
#          93  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -3.659891E-17    0.000000E+00              9.00000E+100
#          94  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -7.361347E-17    0.000000E+00              9.00000E+100
#          95  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -2.074561E-17    0.000000E+00              9.00000E+100
#          96  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -2.442629E-17    0.000000E+00              9.00000E+100
#          97  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.347124E-18    0.000000E+00              9.00000E+100
#          98  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00    6.116672E-18    0.000000E+00              9.00000E+100
#          99  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.061315E-17    0.000000E+00              9.00000E+100
#         100  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.996165E-01    1.000000E+00              9.00000E+100
#         101  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.520130E-01    1.000000E+00              9.00000E+100
#         102  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.117074E-01    1.000000E+00              9.00000E+100
#         103  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.031997E-01    1.000000E+00              9.00000E+100
#         104  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.031997E-01    1.000000E+00              9.00000E+100
#         105  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.835895E-01    1.000000E+00              9.00000E+100
#         106  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.964556E-01    1.000000E+00              9.00000E+100
#         107  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.061926E-01    1.000000E+00              9.00000E+100
#         108  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.061926E-01    1.000000E+00              9.00000E+100
#         109  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.493451E-01    1.000000E+00              9.00000E+100
#         110  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    6.311477E-01    1.000000E+00              9.00000E+100
#         111  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    6.624158E-01    1.000000E+00              9.00000E+100
#         112  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    6.624158E-01    1.000000E+00              9.00000E+100
#         113  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    7.267572E-01    1.000000E+00              9.00000E+100
#         114  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    8.319599E-01    1.000000E+00              9.00000E+100
#         115  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    8.692006E-01    1.000000E+00              9.00000E+100
#         116  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    8.692006E-01    1.000000E+00              9.00000E+100
#         117  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    9.156399E-01    1.000000E+00              9.00000E+100
#         118  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    9.784211E-01    1.000000E+00              9.00000E+100
#         119  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    9.999998E-01    1.000000E+00         u    9.00000E+100
#         120  traj.phases.cruise->initial_boundary_constraint->throttle         i   0.000000E+00    7.529540E-01    1.000000E+00              9.00000E+100
#         121  traj.phases.cruise->final_boundary_constraint->throttle           i   0.000000E+00    8.306914E-01    1.000000E+00              9.00000E+100
#         122  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.879326E-01    1.000000E+00              9.00000E+100
#         123  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.540479E-01    1.000000E+00              9.00000E+100
#         124  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.116875E-01    1.000000E+00              9.00000E+100
#         125  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.996672E-01    1.000000E+00              9.00000E+100
#         126  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.996672E-01    1.000000E+00              9.00000E+100
#         127  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.488847E-01    1.000000E+00              9.00000E+100
#         128  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.828670E-01    1.000000E+00              9.00000E+100
#         129  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.643163E-01    1.000000E+00              9.00000E+100
#         130  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.643163E-01    1.000000E+00              9.00000E+100
#         131  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.229424E-01    1.000000E+00              9.00000E+100
#         132  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    6.315595E-02    1.000000E+00              9.00000E+100
#         133  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.249374E-02    1.000000E+00              9.00000E+100
#         134  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.249374E-02    1.000000E+00              9.00000E+100
#         135  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.320404E-02    1.000000E+00              9.00000E+100
#         136  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.220757E-06    1.000000E+00              9.00000E+100
#         137  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.530569E-03    1.000000E+00              9.00000E+100
#         138  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.530569E-03    1.000000E+00              9.00000E+100
#         139  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.630389E-02    1.000000E+00              9.00000E+100
#         140  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.787200E-02    1.000000E+00              9.00000E+100
#         141  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    6.279606E-02    1.000000E+00              9.00000E+100
#
#
#    Exit Status
#       Inform  Description
#            0  Solve Succeeded
# --------------------------------------------------------------------------------

# %% [markdown]
# Now, let's see the fuel burn:

# %%
optimized_mission_fixed_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
optimized_mission_fixed_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', optimized_mission_fixed_wing_fuel_burn)
print('Aspect ratio:', optimized_mission_fixed_wing_aspect_ratio)
# Out:
# Mission fuel burn, kg: 11255.585785564663
# Aspect ratio: 11.22091

# %% [markdown]
# Optimizing the mission did not have nearly as large of an impact on the fuel burn as optimizing the aspect ratio did.
# However, the fuel burn still decreased.
# Let us now look at the fully coupled case.
#
# ## Optimized Mission Profile, Optimized Aircraft Wing Aspect Ratio
#
# Remember we have already modified the `phase_info` object so that the Mach and altitude profiles are optimized.
# Now we return to the Level 2 way of running the problem with the wing aspect ratio as a design variable.

# %%
from openmdao.core.problem import _clear_problem_names
_clear_problem_names()  # need to reset these to simulate separate runs
from openmdao.utils.reports_system import clear_reports
clear_reports()

# %%
prob = av.AviaryProblem(av.AnalysisScheme.COLLOCATION)

# Load aircraft and options data from user
# Allow for user overrides here
prob.load_inputs(aircraft_filename, phase_info)

prob.check_and_preprocess_inputs()
# Preprocess inputs
prob.add_pre_mission_systems()

prob.add_phases()

prob.add_post_mission_systems()

# Link phases and variables
prob.link_phases()

prob.add_driver(optimizer, max_iter=max_iter)

prob.add_design_variables()

# prob.model.add_design_var(av.Aircraft.Engine.SCALED_SLS_THRUST, lower=25.e3, upper=30.e3, units='lbf', ref=28.e3)
prob.model.add_design_var(av.Aircraft.Wing.ASPECT_RATIO, lower=10., upper=14., ref=12.)

# Load optimization problem formulation
# Detail which variables the optimizer can control
prob.add_objective()

prob.setup()

prob.set_initial_guesses()

prob.run_aviary_problem(make_plots=make_plots)
# Out:
# Unused: aircraft:crew_and_payload:num_non_flight_crew [3]
# Unused: aircraft:nacelle:count_factor [2]
#
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
# /Users/hschilli/Documents/OpenMDAO/dev/I112-level1-reports-location/aviary/subsystems/propulsion/engine_model.py:132: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [initial] 2.0000e-01 == mach [unitless]
#         [initial] 0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [final]   2.1000e-01 == mach [unitless]
#         [final]   0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/recorders/sqlite_recorder.py:227: UserWarning:The existing case recorder file, aviary_history.db, is being overwritten.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.649663 seconds.
# Total jacobian shape: (143, 108)
#
#
# Jacobian shape: (143, 108)  (14.12% nonzero)
# FWD solves: 25   REV solves: 0
# Total colors vs. total size: 25 vs 108  (76.85% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.6497 sec
# Time to compute coloring:   0.1162 sec
# Memory to compute coloring:  -0.0742 MB
# Coloring created on: 2024-02-22 09:57:46
#
# List of user-set options:
#
#                                     Name   Value                used
#                              alpha_for_y = safer-min-dual-infeas  yes
#                         file_print_level = 5                     yes
#                    hessian_approximation = limited-memory        yes
#                            linear_solver = mumps                 yes
#                                 max_iter = 200                   yes
#                                  mu_init = 1e-05                 yes
#                              mu_strategy = monotone              yes
#                       nlp_scaling_method = gradient-based        yes
#                              output_file = reports/problem/IPOPT.out  yes
#                              print_level = 5                     yes
#                       print_user_options = yes                   yes
#                                       sb = yes                   yes
#                                      tol = 1e-06                 yes
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:     1039
# Number of nonzeros in inequality constraint Jacobian.:      749
# Number of nonzeros in Lagrangian Hessian.............:        0
# /Users/hschilli/Documents/OpenMDAO/dev/OpenMDAO/openmdao/core/total_jac.py:1788: DerivativesWarning:Design variables [('traj.climb_1.t_initial', inds=[0])] have no impact on the constraints or objective.
# Total number of variables............................:      108
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      108
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      100
# Total number of inequality constraints...............:       42
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       42
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.07e+01 8.65e-02  -5.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.2692204e-02 2.04e+01 1.06e+00  -5.0 9.28e+00    -  2.60e-03 1.54e-02h  1
#    2  8.8695668e-02 1.94e+01 1.06e+00  -5.0 7.15e+00    -  1.77e-02 4.99e-02h  1
#    3  9.4207737e-02 1.94e+01 1.06e+00  -5.0 9.32e+00    -  6.72e-04 1.68e-03h  1
#    4  1.1461166e-01 1.93e+01 1.06e+00  -5.0 8.10e+00    -  6.28e-04 4.60e-03h  1
#    5  1.1547257e-01 1.93e+01 1.06e+00  -5.0 1.48e+01    -  2.38e-04 2.31e-04h  1
#    6  1.2666211e-01 1.92e+01 1.06e+00  -5.0 1.01e+01    -  3.11e-04 4.25e-03h  1
#    7  1.2810303e-01 1.92e+01 1.12e+00  -5.0 7.07e+00    -  4.53e-04 4.03e-04h  1
#    8  1.4123593e-01 1.91e+01 1.12e+00  -5.0 5.29e+00    -  1.38e-03 4.70e-03h  1
#    9  1.4171880e-01 1.91e+01 1.09e+00  -5.0 9.08e+00    -  1.01e-04 7.71e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.4918377e-01 1.90e+01 1.09e+00  -5.0 3.54e+00    -  2.57e-03 3.48e-03h  1
#   11  1.5729097e-01 1.90e+01 1.08e+00  -5.0 3.52e+00    -  1.12e-03 4.07e-03h  1
#   12  1.6911117e-01 1.88e+01 1.08e+00  -5.0 3.51e+00    -  1.51e-06 5.95e-03h  1
#   13  1.6929513e-01 1.88e+01 1.08e+00  -5.0 1.79e+01    -  3.86e-05 3.15e-05h  1
#   14  1.7492467e-01 1.88e+01 1.08e+00  -5.0 3.49e+00    -  2.55e-03 3.29e-03h  1
#   15  1.7934323e-01 1.87e+01 1.08e+00  -5.0 3.48e+00    -  9.36e-04 2.52e-03h  1
-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.2718584e+00 3.43e-08 5.17e-03  -5.0 2.11e-03    -  1.00e+00 1.00e+00h  1
#   41  2.2717063e+00 2.12e-06 6.89e-02  -5.0 3.24e-02    -  1.00e+00 1.00e+00h  1
#   42  2.2699947e+00 6.49e-05 3.53e-03  -5.0 3.06e-02    -  1.00e+00 1.00e+00h  1
#   43  2.2718031e+00 8.46e-09 1.19e-03  -5.0 2.57e-03    -  1.00e+00 1.00e+00h  1
#   44  2.2717899e+00 3.76e-05 2.68e-03  -5.0 3.49e-03    -  1.00e+00 1.00e+00h  1
#   45  2.2718039e+00 2.44e-08 1.61e-03  -5.0 3.72e-03    -  1.00e+00 5.00e-01h  2
#   46  2.2717807e+00 3.53e-08 5.41e-05  -5.0 2.03e-03    -  1.00e+00 1.00e+00h  1
#   47  2.2717015e+00 2.24e-08 1.26e-04  -7.0 1.01e-03    -  9.91e-01 7.12e-01h  1
#   48  2.2716757e+00 5.49e-09 3.08e-05  -7.0 3.37e-04    -  1.00e+00 1.00e+00h  1
#   49  2.2716774e+00 6.79e-10 7.78e-06  -7.0 4.27e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  2.2716781e+00 3.03e-10 6.87e-06  -7.0 2.10e-05    -  1.00e+00 1.00e+00h  1
#   51  2.2716783e+00 2.42e-10 4.62e-06  -7.0 1.19e-05    -  1.00e+00 1.00e+00h  1
#   52  2.2716786e+00 7.78e-11 1.53e-07  -7.0 4.74e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 52
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.2716786460401810e+00    2.2716786460401810e+00
# Dual infeasibility......:   1.5345392054429460e-07    1.5345392054429460e-07
# Constraint violation....:   7.7833298428890907e-11    7.7833298428890907e-11
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090912637587e-08    9.0909090912637587e-08
# Overall NLP error.......:   1.5345392054429460e-07    1.5345392054429460e-07
#
#
# Number of objective function evaluations             = 57
# Number of objective gradient evaluations             = 53
# Number of equality constraint evaluations            = 57
# Number of inequality constraint evaluations          = 57
# Number of equality constraint Jacobian evaluations   = 53
# Number of inequality constraint Jacobian evaluations = 53
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT                               = 34.649
#
# EXIT: Optimal Solution Found.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                   34.6513
#        User Objective Time :      22.4182
#        User Sensitivity Time :    11.7924
#        Interface Time :            0.2236
#        Opt Solver Time:            0.2170
#     Calls to Objective Function :      58
#     Calls to Sens Function :           54
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.271679E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                            Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0                        c     7.407407E-01     1.183506E+00     1.481481E+00
#           1  aircraft:wing:aspect_ratio_0                       c     8.333333E-01     1.166667E+00     1.166667E+00          u
#           2  traj.climb_1.t_initial_0                           c    -1.666667E+18     0.000000E+00     1.666667E+18
#           3  traj.climb_1.t_duration_0                          c     5.000000E-01     6.447637E-01     1.500000E+00
#           4  traj.climb_1.states:mass_0                         c     0.000000E+00     7.943554E+00     1.000000E+17
#           5  traj.climb_1.states:mass_1                         c     0.000000E+00     7.928087E+00     1.000000E+17
#           6  traj.climb_1.states:mass_2                         c     0.000000E+00     7.923468E+00     1.000000E+17
#           7  traj.climb_1.states:mass_3                         c     0.000000E+00     7.903121E+00     1.000000E+17
#           8  traj.climb_1.states:mass_4                         c     0.000000E+00     7.877149E+00     1.000000E+17
#          75  traj.descent_1.states:mass_1                       c     0.000000E+00     6.976256E+00     1.000000E+17
#          76  traj.descent_1.states:mass_2                       c     0.000000E+00     6.974911E+00     1.000000E+17
#          77  traj.descent_1.states:mass_3                       c     0.000000E+00     6.968782E+00     1.000000E+17
#          78  traj.descent_1.states:mass_4                       c     0.000000E+00     6.960790E+00     1.000000E+17
#          79  traj.descent_1.states:mass_5                       c     0.000000E+00     6.958390E+00     1.000000E+17
#          80  traj.descent_1.states:mass_6                       c     0.000000E+00     6.952160E+00     1.000000E+17
#          81  traj.descent_1.states:mass_7                       c     0.000000E+00     6.944640E+00     1.000000E+17
#          82  traj.descent_1.states:mass_8                       c     0.000000E+00     6.942609E+00     1.000000E+17
#          83  traj.descent_1.states:mass_9                       c     0.000000E+00     6.938811E+00     1.000000E+17
#          84  traj.descent_1.states:mass_10                      c     0.000000E+00     6.933558E+00     1.000000E+17
#          85  traj.descent_1.states:mass_11                      c     0.000000E+00     6.931791E+00     1.000000E+17
#          86  traj.descent_1.states:mass_12                      c     0.000000E+00     6.929717E+00     1.000000E+17
#          87  traj.descent_1.states:mass_13                      c     0.000000E+00     6.926634E+00     1.000000E+17
#          88  traj.descent_1.states:mass_14                      c     0.000000E+00     6.925594E+00     1.000000E+17
#          89  traj.descent_1.states:distance_0                   c     0.000000E+00     3.469914E+00     1.000000E+15
#          90  traj.descent_1.states:distance_1                   c     0.000000E+00     3.502753E+00     1.000000E+15
#          91  traj.descent_1.states:distance_2                   c     0.000000E+00     3.512918E+00     1.000000E+15
#          92  traj.descent_1.states:distance_3                   c     0.000000E+00     3.558917E+00     1.000000E+15
#          93  traj.descent_1.states:distance_4                   c     0.000000E+00     3.618124E+00     1.000000E+15
#          94  traj.descent_1.states:distance_5                   c     0.000000E+00     3.635798E+00     1.000000E+15
#          95  traj.descent_1.states:distance_6                   c     0.000000E+00     3.681238E+00     1.000000E+15
#          96  traj.descent_1.states:distance_7                   c     0.000000E+00     3.737278E+00     1.000000E+15
#          97  traj.descent_1.states:distance_8                   c     0.000000E+00     3.753351E+00     1.000000E+15
#          98  traj.descent_1.states:distance_9                   c     0.000000E+00     3.781990E+00     1.000000E+15
#          99  traj.descent_1.states:distance_10                  c     0.000000E+00     3.816359E+00     1.000000E+15
#         100  traj.descent_1.states:distance_11                  c     0.000000E+00     3.825962E+00     1.000000E+15
#         101  traj.descent_1.states:distance_12                  c     0.000000E+00     3.835988E+00     1.000000E+15
#         102  traj.descent_1.states:distance_13                  c     0.000000E+00     3.848514E+00     1.000000E+15
#         103  traj.descent_1.states:distance_14                  c     0.000000E+00     3.852160E+00     1.000000E+15
#         104  traj.descent_1.polynomial_controls:mach_0          c     3.800000E-01     1.469406E+00     1.680000E+00
#         105  traj.descent_1.polynomial_controls:mach_1          c     3.800000E-01     4.200000E-01     1.680000E+00
#         106  traj.descent_1.polynomial_controls:altitude_0      c     0.000000E+00     9.999994E-01     1.000000E+00          u
#         107  traj.descent_1.polynomial_controls:altitude_1      c     0.000000E+00     0.000000E+00     1.000000E+00          l
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                           Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                                e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                                 e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           2  traj.linkages.climb_1:altitude_final|cruise:altitude_initial      e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           3  traj.linkages.climb_1:mach_final|cruise:mach_initial              e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           4  traj.linkages.cruise:altitude_final|descent_1:altitude_initial    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           5  traj.linkages.cruise:mach_final|descent_1:mach_initial            e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           6  traj.phases.climb_1->initial_boundary_constraint->mach            e   2.000000E-01    2.000000E-01    2.000000E-01              9.00000E+100
#           7  traj.phases.climb_1->initial_boundary_constraint->altitude        e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00    4.160457E-17    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.289456E-14    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -3.733567E-14    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -9.560209E-14    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.074770E-13    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -4.193633E-13    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -5.943597E-13    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -9.092418E-13    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.432314E-12    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.341224E-12    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.610107E-12    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -2.087021E-12    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.084055E-12    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.225413E-12    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:mass                  e   0.000000E+00   -1.331282E-12    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00    4.520700E-20    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -3.187094E-18    0.000000E+00              9.00000E+100
#          25  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -7.368741E-18    0.000000E+00              9.00000E+100
#          26  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -1.708023E-17    0.000000E+00              9.00000E+100
#          27  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -2.949801E-17    0.000000E+00              9.00000E+100
#          28  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -4.487021E-17    0.000000E+00              9.00000E+100
#          29  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -5.872478E-17    0.000000E+00              9.00000E+100
#          30  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -7.178692E-17    0.000000E+00              9.00000E+100
#          31  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -8.880064E-17    0.000000E+00              9.00000E+100
#          32  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -7.949229E-17    0.000000E+00              9.00000E+100
#          33  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -8.383159E-17    0.000000E+00              9.00000E+100
#          34  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -9.140229E-17    0.000000E+00              9.00000E+100
#          35  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -4.303706E-17    0.000000E+00              9.00000E+100
#          36  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -4.841670E-17    0.000000E+00              9.00000E+100
#          37  traj.climb_1.collocation_constraint.defects:distance              e   0.000000E+00   -4.579469E-17    0.000000E+00              9.00000E+100
#          38  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -6.287206E-12    0.000000E+00              9.00000E+100
#          39  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -8.038840E-12    0.000000E+00              9.00000E+100
#          40  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -1.040778E-11    0.000000E+00              9.00000E+100
#          41  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -2.276347E-11    0.000000E+00              9.00000E+100
#          42  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -2.966621E-11    0.000000E+00              9.00000E+100
#          43  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -3.879367E-11    0.000000E+00              9.00000E+100
#          44  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -4.944408E-11    0.000000E+00              9.00000E+100
#          45  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -5.822172E-11    0.000000E+00              9.00000E+100
#          46  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -6.968967E-11    0.000000E+00              9.00000E+100
#          47  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -6.155924E-11    0.000000E+00              9.00000E+100
#          48  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -6.713333E-11    0.000000E+00              9.00000E+100
#          49  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -7.783330E-11    0.000000E+00              9.00000E+100
#          50  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -3.917528E-11    0.000000E+00              9.00000E+100
#          51  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -4.017107E-11    0.000000E+00              9.00000E+100
#          52  traj.cruise.collocation_constraint.defects:mass                   e   0.000000E+00   -4.211019E-11    0.000000E+00              9.00000E+100
#          53  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00   -4.383361E-16    0.000000E+00              9.00000E+100
#          54  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    5.825838E-18    0.000000E+00              9.00000E+100
#          55  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    6.301227E-16    0.000000E+00              9.00000E+100
#          56  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.685711E-15    0.000000E+00              9.00000E+100
#          57  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    3.577496E-15    0.000000E+00              9.00000E+100
#          58  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    6.180782E-15    0.000000E+00              9.00000E+100
#          59  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    8.356634E-15    0.000000E+00              9.00000E+100
#          60  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.102845E-14    0.000000E+00              9.00000E+100
#          61  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.473063E-14    0.000000E+00              9.00000E+100
#          62  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.337575E-14    0.000000E+00              9.00000E+100
#          63  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.529752E-14    0.000000E+00              9.00000E+100
#          64  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.791984E-14    0.000000E+00              9.00000E+100
#          65  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    9.164976E-15    0.000000E+00              9.00000E+100
#          66  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    9.659240E-15    0.000000E+00              9.00000E+100
#          67  traj.cruise.collocation_constraint.defects:distance               e   0.000000E+00    1.030521E-14    0.000000E+00              9.00000E+100
#          68  traj.phases.descent_1->final_boundary_constraint->mach            e   2.100000E-01    2.100000E-01    2.100000E-01              9.00000E+100
#          69  traj.phases.descent_1->final_boundary_constraint->altitude        e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          70  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -7.691508E-12    0.000000E+00              9.00000E+100
#          71  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -6.845141E-12    0.000000E+00              9.00000E+100
#          72  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -6.251749E-12    0.000000E+00              9.00000E+100
#          73  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.237465E-11    0.000000E+00              9.00000E+100
#          74  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.046252E-11    0.000000E+00              9.00000E+100
#          75  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -7.668835E-12    0.000000E+00              9.00000E+100
#          76  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -7.979442E-12    0.000000E+00              9.00000E+100
#          77  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -5.930257E-12    0.000000E+00              9.00000E+100
#          78  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -3.487122E-12    0.000000E+00              9.00000E+100
#          79  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.616788E-12    0.000000E+00              9.00000E+100
#          80  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -7.550712E-13    0.000000E+00              9.00000E+100
#          81  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -1.899788E-13    0.000000E+00              9.00000E+100
#          82  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -5.290197E-14    0.000000E+00              9.00000E+100
#          83  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -2.374200E-14    0.000000E+00              9.00000E+100
#          84  traj.descent_1.collocation_constraint.defects:mass                e   0.000000E+00   -3.736899E-15    0.000000E+00              9.00000E+100
#          85  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.032112E-15    0.000000E+00              9.00000E+100
#          86  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -9.647714E-16    0.000000E+00              9.00000E+100
#          87  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -9.210849E-16    0.000000E+00              9.00000E+100
#          88  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.875032E-15    0.000000E+00              9.00000E+100
#          89  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.686761E-15    0.000000E+00              9.00000E+100
#          90  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.483979E-15    0.000000E+00              9.00000E+100
#          91  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.684387E-15    0.000000E+00              9.00000E+100
#          92  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.413692E-15    0.000000E+00              9.00000E+100
#          93  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.088679E-15    0.000000E+00              9.00000E+100
#          94  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -8.063535E-16    0.000000E+00              9.00000E+100
#          95  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -6.057248E-16    0.000000E+00              9.00000E+100
#          96  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -3.740140E-16    0.000000E+00              9.00000E+100
#          97  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -1.132046E-16    0.000000E+00              9.00000E+100
#          98  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -8.111579E-17    0.000000E+00              9.00000E+100
#          99  traj.descent_1.collocation_constraint.defects:distance            e   0.000000E+00   -2.498339E-17    0.000000E+00              9.00000E+100
#         100  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.031586E-01    1.000000E+00              9.00000E+100
#         101  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.774132E-01    1.000000E+00              9.00000E+100
#         102  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.582715E-01    1.000000E+00              9.00000E+100
#         103  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.549790E-01    1.000000E+00              9.00000E+100
#         104  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.549790E-01    1.000000E+00              9.00000E+100
#         105  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.535162E-01    1.000000E+00              9.00000E+100
#         106  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.807110E-01    1.000000E+00              9.00000E+100
#         107  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.934446E-01    1.000000E+00              9.00000E+100
#         108  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    4.934446E-01    1.000000E+00              9.00000E+100
#         109  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    5.424995E-01    1.000000E+00              9.00000E+100
#         110  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    6.285302E-01    1.000000E+00              9.00000E+100
#         111  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    6.589271E-01    1.000000E+00              9.00000E+100
#         112  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    6.589271E-01    1.000000E+00              9.00000E+100
#         113  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    7.242132E-01    1.000000E+00              9.00000E+100
#         114  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    8.317052E-01    1.000000E+00              9.00000E+100
#         115  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    8.696496E-01    1.000000E+00              9.00000E+100
#         116  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    8.696496E-01    1.000000E+00              9.00000E+100
#         117  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    9.177699E-01    1.000000E+00              9.00000E+100
#         118  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    9.783996E-01    1.000000E+00              9.00000E+100
#         119  traj.phases.climb_1->path_constraint->throttle                    i   0.000000E+00    9.999996E-01    1.000000E+00         u    9.00000E+100
#         120  traj.phases.cruise->initial_boundary_constraint->throttle         i   0.000000E+00    7.028763E-01    1.000000E+00              9.00000E+100
#         121  traj.phases.cruise->final_boundary_constraint->throttle           i   0.000000E+00    7.649268E-01    1.000000E+00              9.00000E+100
#         122  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.000066E-01    1.000000E+00              9.00000E+100
#         123  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.673220E-01    1.000000E+00              9.00000E+100
#         124  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.261238E-01    1.000000E+00              9.00000E+100
#         125  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.146029E-01    1.000000E+00              9.00000E+100
#         126  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.146029E-01    1.000000E+00              9.00000E+100
#         127  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.650422E-01    1.000000E+00              9.00000E+100
#         128  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.017415E-01    1.000000E+00              9.00000E+100
#         129  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.838133E-01    1.000000E+00              9.00000E+100
#         130  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.838133E-01    1.000000E+00              9.00000E+100
#         131  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.431739E-01    1.000000E+00              9.00000E+100
#         132  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    9.282132E-02    1.000000E+00              9.00000E+100
#         133  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    7.159711E-02    1.000000E+00              9.00000E+100
#         134  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    7.159711E-02    1.000000E+00              9.00000E+100
#         135  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    3.538529E-02    1.000000E+00              9.00000E+100
#         136  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    4.246797E-03    1.000000E+00              9.00000E+100
#         137  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.604039E-04    1.000000E+00              9.00000E+100
#         138  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    2.604039E-04    1.000000E+00              9.00000E+100
#         139  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    7.644390E-07    1.000000E+00         l    9.00000E+100
#         140  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    8.828352E-03    1.000000E+00              9.00000E+100
#         141  traj.phases.descent_1->path_constraint->throttle                  i   0.000000E+00    1.444580E-02    1.000000E+00              9.00000E+100
#
#
#    Exit Status
#       Inform  Description
#            0  Solve Succeeded
# --------------------------------------------------------------------------------
# False

# %% [markdown]
# All right, let's check out this final case's fuel burn value:

# %%
optimized_mission_optimized_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
optimized_mission_optimized_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', optimized_mission_optimized_wing_fuel_burn)
print('Aspect ratio:', optimized_mission_optimized_wing_aspect_ratio)
# Out:
# Mission fuel burn, kg: 10304.16100935757
# Aspect ratio: 13.999998590641077

# %% [markdown]
# Cool, it's the lowest yet!
# Let's discuss these results in more detail now.
#
# ## Summary and Takeaways
#
# We have showcased one of Aviary's most powerful capabilities here -- the ability to simultaneously design an aircraft and optimal trajectory.
# By building up problem complexity, we can see how optimizing different parts of the problem lead to optimization objective improvements.
#
# Here is a summary table of the results:

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Case': ['Fixed Mission, Fixed Wing', 'Fixed Mission, Optimized Wing', 'Optimized Mission, Fixed Wing', 'Optimized Mission, Optimized Wing'],
    'Optimize Mission': ['-', '-', '✓', '✓'],
    'Optimize Wing': ['-', '✓', '-', '✓'],
    'Aspect Ratio': [fixed_mission_fixed_wing_aspect_ratio, fixed_mission_optimized_wing_aspect_ratio, optimized_mission_fixed_wing_aspect_ratio, optimized_mission_optimized_wing_aspect_ratio],
    'Fuel Burn Value': [fixed_mission_fixed_wing_fuel_burn, fixed_mission_optimized_wing_fuel_burn, optimized_mission_fixed_wing_fuel_burn, optimized_mission_optimized_wing_fuel_burn]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data).round(2)

# Display the DataFrame
df
# Out:
#                                 Case Optimize Mission Optimize Wing  \
# 0          Fixed Mission, Fixed Wing                -             -
# 1      Fixed Mission, Optimized Wing                -             ✓
# 2      Optimized Mission, Fixed Wing                ✓             -
# 3  Optimized Mission, Optimized Wing                ✓             ✓
#
#    Aspect Ratio  Fuel Burn Value
# 0         11.22         11398.92
# 1         14.00         10445.60
# 2         11.22         11255.59
# 3         14.00         10304.16

# %% [markdown]
# We see that the fully coupled case finds the lowest fuel burn value, as expected.
# In both cases where the wing aspect ratio is optimized, it moves to the higher bound.
#
# If we didn't simultaneously design the aircraft and the mission, you would have to manually iterate by first optimizing the aircraft, then the mission, then the aircraft again, etc.
# This cumbersome process is known as sequential optimization and can lead to non-optimal results for coupled systems, as detailed in Section 13.1 of the [Engineering Design Optimization textbook](https://flowlab.groups.et.byu.net/mdobook.pdf) (available for free).
#
# Aviary is unique in its ability to solve these coupled systems using efficient gradient-based optimization.
#
# This doc page contains a simple example, but the true power of coupled multidisciplinary optimization lies in solving more complex design problems.
# We hope that you can effectively use Aviary to optimally design the next generation of exciting aircraft!
