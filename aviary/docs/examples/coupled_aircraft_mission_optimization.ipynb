# %% [markdown]
# # Coupled Aircraft-Mission Optimization
#
# One of the most exciting features of Aviary is the ability to formulate and solve coupled aircraft-mission design optimization problems.
# Here, we mean that we are finding the optimal aircraft design parameters while simultaneously finding the optimal mission trajectory.
# The reason why this is so valuable is that it enables exploration of a larger design space much more efficiently.
#
# Solving coupled design-mission problems leads to optimal designs that would not be findable without simultaneously designing the aircraft and the trajectory.
# This is especially useful for unconventional aircraft designs, operations with complex missions, and many more future-focused studies than what is commonly flying today.
#
# This doc page builds up a coupled design problem and explains what we're doing along the way.
# This process is relatively straightforward in Aviary.
# We will briefly discuss the optimal results, but that is not necessarily the focus here.
# Instead, we want to showcase how to do a simple coupled design study in Aviary.
#
# You can use this as a starting point for your own exciting aircraft and mission design studies.
#
# ## Problem Definition and Explanation
#
# We will use a conventional single-aisle commercial aircraft design as our starting point.
# For all of these examples we allow the aircraft to be sized by the optimizer.
# This means the gross takeoff weight is controlled to meet a mass balance.
#
# We will perform four different optimization cases as part of this study:
#
# - fixed mission profile, fixed aircraft wing aspect ratio
# - fixed mission profile, optimized aircraft wing aspect ratio
# - optimized mission profile, fixed aircraft wing aspect ratio
# - optimized mission profile, optimized aircraft wing aspect ratio
#
# We'll provide more detail individually for each case.
#
# When we call Aviary, we will use a common `phase_info` object that we modify for each optimization case shown here:

# %%
phase_info = {
    "pre_mission": {"include_takeoff": False, "optimize_mass": True},
    "climb_1": {
        "subsystem_options": {"core_aerodynamics": {"method": "computed"}},
        "user_options": {
            "optimize_mach": False,
            "optimize_altitude": False,
            "polynomial_control_order": 1,
            "num_segments": 5,
            "order": 3,
            "solve_for_range": False,
            "initial_mach": (0.2, "unitless"),
            "final_mach": (0.72, "unitless"),
            "mach_bounds": ((0.18, 0.84), "unitless"),
            "initial_altitude": (0.0, "ft"),
            "final_altitude": (32500.0, "ft"),
            "altitude_bounds": ((0.0, 33000.0), "ft"),
            "throttle_enforcement": "path_constraint",
            "fix_initial": True,
            "constrain_final": False,
            "fix_duration": False,
            "initial_bounds": ((0.0, 0.0), "min"),
            "duration_bounds": ((35.0, 105.0), "min"),
        },
        "initial_guesses": {"times": ([0, 70], "min")},
    },
    "cruise": {
        "subsystem_options": {"core_aerodynamics": {"method": "computed"}},
        "user_options": {
            "optimize_mach": False,
            "optimize_altitude": False,
            "polynomial_control_order": 1,
            "num_segments": 5,
            "order": 3,
            "solve_for_range": False,
            "initial_mach": (0.72, "unitless"),
            "final_mach": (0.80, "unitless"),
            "mach_bounds": ((0.7, 0.84), "unitless"),
            "initial_altitude": (32500.0, "ft"),
            "final_altitude": (36000.0, "ft"),
            "altitude_bounds": ((32000.0, 36500.0), "ft"),
            "throttle_enforcement": "boundary_constraint",
            "fix_initial": False,
            "constrain_final": False,
            "fix_duration": False,
            "initial_bounds": ((35.0, 105.0), "min"),
            "duration_bounds": ((91.5, 274.5), "min"),
        },
        "initial_guesses": {"times": ([70, 183], "min")},
    },
    "descent_1": {
        "subsystem_options": {"core_aerodynamics": {"method": "computed"}},
        "user_options": {
            "optimize_mach": False,
            "optimize_altitude": False,
            "polynomial_control_order": 1,
            "num_segments": 5,
            "order": 3,
            "solve_for_range": False,
            "initial_mach": (0.72, "unitless"),
            "final_mach": (0.21, "unitless"),
            "mach_bounds": ((0.19, 0.84), "unitless"),
            "initial_altitude": (36000.0, "ft"),
            "final_altitude": (0.0, "ft"),
            "altitude_bounds": ((0.0, 36500.0), "ft"),
            "throttle_enforcement": "path_constraint",
            "fix_initial": False,
            "constrain_final": True,
            "fix_duration": False,
            "initial_bounds": ((126.5, 379.5), "min"),
            "duration_bounds": ((25.0, 75.0), "min"),
        },
        "initial_guesses": {"times": ([253, 50], "min")},
    },
    "post_mission": {
        "include_landing": False,
        "constrain_range": True,
        "target_range": (2080, "nmi"),
    },
}

# %% [markdown]
# Now, let us explain each case, formulate the Aviary problem, and optimize.
# We'll discuss the results from each case and explain why they vary.
#
# ## Fixed Mission Profile, Fixed Aircraft Wing Aspect Ratio
#
# First, let us run Aviary with a simple setup: fly a prescribed mission profile with an unchanged wing design.
# Here we are varying the durations of each of the phases (climb, cruise, and descent) to minimize fuel burn across the mission.
# The altitude and Mach profiles of the mission are fixed because `optimize_altitude = False` and `optimize_mach = False` for each of the phases in the `phase_info` object.

# %%
import aviary.api as av

aircraft_filename = 'models/test_aircraft/aircraft_for_bench_FwFm.csv'
mission_method = "simple"
mass_method = "FLOPS"
optimizer = "IPOPT"
make_plots = True
max_iter = 200

prob = av.run_aviary(aircraft_filename, phase_info,
                    mission_method=mission_method, mass_method=mass_method,
                    optimizer=optimizer, make_plots=make_plots, max_iter=max_iter)
# Out:
# /home/kmoore/Work/OpenMDAO/plugins/om-Aviary/aviary/subsystems/propulsion/engine_deck.py:198: UserWarning: <mission:summary:fuel_flow_scaler> is a required option for EngineDecks, but has not been specified for EngineDeck <engine>. The default value will be used.
#   warnings.warn(
# /home/kmoore/Work/OpenMDAO/plugins/om-Aviary/aviary/subsystems/propulsion/engine_model.py:131: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
#
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /home/kmoore/Work/OpenMDAO/virtual_py38/lib/python3.8/site-packages/dymos/transcriptions/transcription_base.py:448: OpenMDAOWarning:'traj.phases.cruise' <class Phase>
#   Non-default solvers are required
#     implicit duration: False
#     solved segments: False
#     input initial: True
#   Setting `traj.phases.cruise.nonlinear_solver = om.NewtonSolver(iprint=0, solve_subsystems=True, maxiter=1000, stall_limit=3)`
#   Explicitly set traj.phases.cruise.nonlinear_solver to override.
#   Setting `traj.phases.cruise.linear_solver = om.DirectSolver(iprint=2)`
#   Explicitly set traj.phases.cruise.linear_solver to override.
#   Set `traj.phases.cruise.options["auto_solvers"] = False` to disable this behavior.
# /home/kmoore/Work/OpenMDAO/virtual_py38/lib/python3.8/site-packages/dymos/transcriptions/transcription_base.py:448: OpenMDAOWarning:'traj.phases.descent_1' <class Phase>
#   Non-default solvers are required
#     implicit duration: False
#     solved segments: False
#     input initial: True
#   Setting `traj.phases.descent_1.nonlinear_solver = om.NewtonSolver(iprint=0, solve_subsystems=True, maxiter=1000, stall_limit=3)`
#   Explicitly set traj.phases.descent_1.nonlinear_solver to override.
#   Setting `traj.phases.descent_1.linear_solver = om.DirectSolver(iprint=2)`
#   Explicitly set traj.phases.descent_1.linear_solver to override.
#   Set `traj.phases.descent_1.options["auto_solvers"] = False` to disable this behavior.
# /home/kmoore/Work/OpenMDAO/OpenMDAO/openmdao/recorders/sqlite_recorder.py:227: UserWarning:The existing case recorder file, dymos_solution.db, is being overwritten.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.470479 seconds.
# Total jacobian shape: (135, 94)
#
#
# Jacobian shape: (135, 94)  (12.54% nonzero)
# FWD solves: 22   REV solves: 0
# Total colors vs. total size: 22 vs 94  (76.60% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.4705 sec
# Time to compute coloring:   0.0608 sec
# Memory to compute coloring:   0.2578 MB
# Coloring created on: 2024-01-08 15:38:32
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                   12.6814
#        User Objective Time :      10.4261
#        User Sensitivity Time :     2.1736
#        Interface Time :            0.0518
#        Opt Solver Time:            0.0299
#     Calls to Objective Function :      31
#     Calls to Sens Function :           20
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.513031E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                             Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0         c     7.407407E-01     1.204724E+00     1.481481E+00
#           1  traj.climb_1.t_duration_0           c     5.000000E-01     8.028197E-01     1.500000E+00
#           2  traj.climb_1.states:mass_0          c     0.000000E+00     7.937914E+00     1.000000E+17
#           3  traj.climb_1.states:mass_1          c     0.000000E+00     7.916114E+00     1.000000E+17
#           4  traj.climb_1.states:mass_2          c     0.000000E+00     7.909733E+00     1.000000E+17
#           5  traj.climb_1.states:mass_3          c     0.000000E+00     7.882277E+00     1.000000E+17
#           6  traj.climb_1.states:mass_4          c     0.000000E+00     7.848535E+00     1.000000E+17
#           7  traj.climb_1.states:mass_5          c     0.000000E+00     7.838356E+00     1.000000E+17
#           8  traj.climb_1.states:mass_6          c     0.000000E+00     7.811412E+00     1.000000E+17
#           9  traj.climb_1.states:mass_7          c     0.000000E+00     7.774984E+00     1.000000E+17
#          10  traj.climb_1.states:mass_8          c     0.000000E+00     7.763435E+00     1.000000E+17
#          11  traj.climb_1.states:mass_9          c     0.000000E+00     7.741169E+00     1.000000E+17
#          12  traj.climb_1.states:mass_10         c     0.000000E+00     7.710195E+00     1.000000E+17
#          13  traj.climb_1.states:mass_11         c     0.000000E+00     7.700295E+00     1.000000E+17
#          14  traj.climb_1.states:mass_12         c     0.000000E+00     7.689160E+00     1.000000E+17
#          15  traj.climb_1.states:mass_13         c     0.000000E+00     7.673681E+00     1.000000E+17
#          16  traj.climb_1.states:mass_14         c     0.000000E+00     7.668746E+00     1.000000E+17
#          17  traj.climb_1.states:range_0         c     0.000000E+00     1.005878E-02     1.000000E+15
#          18  traj.climb_1.states:range_1         c     0.000000E+00     2.555018E-02     1.000000E+15
#          19  traj.climb_1.states:range_2         c     0.000000E+00     3.083923E-02     1.000000E+15
#          20  traj.climb_1.states:range_3         c     0.000000E+00     5.800505E-02     1.000000E+15
#          21  traj.climb_1.states:range_4         c     0.000000E+00     1.019399E-01     1.000000E+15
#          22  traj.climb_1.states:range_5         c     0.000000E+00     1.173710E-01     1.000000E+15
#          23  traj.climb_1.states:range_6         c     0.000000E+00     1.630119E-01     1.000000E+15
#          24  traj.climb_1.states:range_7         c     0.000000E+00     2.344742E-01     1.000000E+15
#          25  traj.climb_1.states:range_8         c     0.000000E+00     2.590846E-01     1.000000E+15
#          26  traj.climb_1.states:range_9         c     0.000000E+00     3.091096E-01     1.000000E+15
#          27  traj.climb_1.states:range_10        c     0.000000E+00     3.836524E-01     1.000000E+15
#          28  traj.climb_1.states:range_11        c     0.000000E+00     4.085420E-01     1.000000E+15
#          29  traj.climb_1.states:range_12        c     0.000000E+00     4.371734E-01     1.000000E+15
#          30  traj.climb_1.states:range_13        c     0.000000E+00     4.779146E-01     1.000000E+15
#          31  traj.climb_1.states:range_14        c     0.000000E+00     4.911032E-01     1.000000E+15
#          32  traj.cruise.t_duration_0            c     5.000000E-01     1.229461E+00     1.500000E+00
#          33  traj.cruise.states:mass_0           c     0.000000E+00     7.634434E+00     1.000000E+17
#          34  traj.cruise.states:mass_1           c     0.000000E+00     7.587183E+00     1.000000E+17
#          35  traj.cruise.states:mass_2           c     0.000000E+00     7.572251E+00     1.000000E+17
#          36  traj.cruise.states:mass_3           c     0.000000E+00     7.502557E+00     1.000000E+17
#          37  traj.cruise.states:mass_4           c     0.000000E+00     7.406773E+00     1.000000E+17
#          38  traj.cruise.states:mass_5           c     0.000000E+00     7.376547E+00     1.000000E+17
#          39  traj.cruise.states:mass_6           c     0.000000E+00     7.294437E+00     1.000000E+17
#          40  traj.cruise.states:mass_7           c     0.000000E+00     7.181487E+00     1.000000E+17
#          41  traj.cruise.states:mass_8           c     0.000000E+00     7.145806E+00     1.000000E+17
#          42  traj.cruise.states:mass_9           c     0.000000E+00     7.077083E+00     1.000000E+17
#          43  traj.cruise.states:mass_10          c     0.000000E+00     6.982203E+00     1.000000E+17
#          44  traj.cruise.states:mass_11          c     0.000000E+00     6.952148E+00     1.000000E+17
#          45  traj.cruise.states:mass_12          c     0.000000E+00     6.918382E+00     1.000000E+17
#          46  traj.cruise.states:mass_13          c     0.000000E+00     6.871650E+00     1.000000E+17
#          47  traj.cruise.states:mass_14          c     0.000000E+00     6.856817E+00     1.000000E+17
#          48  traj.cruise.states:range_0          c     0.000000E+00     6.129092E-01     1.000000E+15
#          49  traj.cruise.states:range_1          c     0.000000E+00     7.817711E-01     1.000000E+15
#          50  traj.cruise.states:range_2          c     0.000000E+00     8.354070E-01     1.000000E+15
#          51  traj.cruise.states:range_3          c     0.000000E+00     1.087462E+00     1.000000E+15
#          52  traj.cruise.states:range_4          c     0.000000E+00     1.438540E+00     1.000000E+15
#          53  traj.cruise.states:range_5          c     0.000000E+00     1.550447E+00     1.000000E+15
#          54  traj.cruise.states:range_6          c     0.000000E+00     1.857037E+00     1.000000E+15
#          55  traj.cruise.states:range_7          c     0.000000E+00     2.284676E+00     1.000000E+15
#          56  traj.cruise.states:range_8          c     0.000000E+00     2.421130E+00     1.000000E+15
#          57  traj.cruise.states:range_9          c     0.000000E+00     2.685447E+00     1.000000E+15
#          58  traj.cruise.states:range_10         c     0.000000E+00     3.053375E+00     1.000000E+15
#          59  traj.cruise.states:range_11         c     0.000000E+00     3.170600E+00     1.000000E+15
#          60  traj.cruise.states:range_12         c     0.000000E+00     3.302479E+00     1.000000E+15
#          61  traj.cruise.states:range_13         c     0.000000E+00     3.485214E+00     1.000000E+15
#          62  traj.cruise.states:range_14         c     0.000000E+00     3.543233E+00     1.000000E+15
#          63  traj.descent_1.t_duration_0         c     5.000000E-01     7.054124E-01     1.500000E+00
#          64  traj.descent_1.states:mass_0        c     0.000000E+00     6.854580E+00     1.000000E+17
#          65  traj.descent_1.states:mass_1        c     0.000000E+00     6.851564E+00     1.000000E+17
#          66  traj.descent_1.states:mass_2        c     0.000000E+00     6.850626E+00     1.000000E+17
#          67  traj.descent_1.states:mass_3        c     0.000000E+00     6.846377E+00     1.000000E+17
#          68  traj.descent_1.states:mass_4        c     0.000000E+00     6.840914E+00     1.000000E+17
#          69  traj.descent_1.states:mass_5        c     0.000000E+00     6.839295E+00     1.000000E+17
#          70  traj.descent_1.states:mass_6        c     0.000000E+00     6.835187E+00     1.000000E+17
#          71  traj.descent_1.states:mass_7        c     0.000000E+00     6.830313E+00     1.000000E+17
#          72  traj.descent_1.states:mass_8        c     0.000000E+00     6.828958E+00     1.000000E+17
#          73  traj.descent_1.states:mass_9        c     0.000000E+00     6.826323E+00     1.000000E+17
#          74  traj.descent_1.states:mass_10       c     0.000000E+00     6.822439E+00     1.000000E+17
#          75  traj.descent_1.states:mass_11       c     0.000000E+00     6.821074E+00     1.000000E+17
#          76  traj.descent_1.states:mass_12       c     0.000000E+00     6.819444E+00     1.000000E+17
#          77  traj.descent_1.states:mass_13       c     0.000000E+00     6.816968E+00     1.000000E+17
#          78  traj.descent_1.states:mass_14       c     0.000000E+00     6.816119E+00     1.000000E+17
#          79  traj.descent_1.states:range_0       c     0.000000E+00     3.561773E+00     1.000000E+15
#          80  traj.descent_1.states:range_1       c     0.000000E+00     3.586639E+00     1.000000E+15
#          81  traj.descent_1.states:range_2       c     0.000000E+00     3.594333E+00     1.000000E+15
#          82  traj.descent_1.states:range_3       c     0.000000E+00     3.629169E+00     1.000000E+15
#          83  traj.descent_1.states:range_4       c     0.000000E+00     3.674030E+00     1.000000E+15
#          84  traj.descent_1.states:range_5       c     0.000000E+00     3.687429E+00     1.000000E+15
#          85  traj.descent_1.states:range_6       c     0.000000E+00     3.721896E+00     1.000000E+15
#          86  traj.descent_1.states:range_7       c     0.000000E+00     3.764458E+00     1.000000E+15
#          87  traj.descent_1.states:range_8       c     0.000000E+00     3.776681E+00     1.000000E+15
#          88  traj.descent_1.states:range_9       c     0.000000E+00     3.798485E+00     1.000000E+15
#          89  traj.descent_1.states:range_10      c     0.000000E+00     3.824711E+00     1.000000E+15
#          90  traj.descent_1.states:range_11      c     0.000000E+00     3.832057E+00     1.000000E+15
#          91  traj.descent_1.states:range_12      c     0.000000E+00     3.839737E+00     1.000000E+15
#          92  traj.descent_1.states:range_13      c     0.000000E+00     3.849355E+00     1.000000E+15
#          93  traj.descent_1.states:range_14      c     0.000000E+00     3.852160E+00     1.000000E+15
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                      Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                           e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                            e   0.000000E+00    8.731149E-16    0.000000E+00              9.00000E+100
#           2  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -4.366791E-17    0.000000E+00              9.00000E+100
#           3  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -7.563827E-18    0.000000E+00              9.00000E+100
#           4  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -3.236614E-17    0.000000E+00              9.00000E+100
#           5  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -9.034982E-17    0.000000E+00              9.00000E+100
#           6  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.317078E-16    0.000000E+00              9.00000E+100
#           7  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -9.879205E-17    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.627271E-16    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.478852E-16    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.582425E-16    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.510665E-16    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.267682E-16    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.658808E-16    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.148215E-17    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.164917E-16    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.288709E-16    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    5.431883E-18    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    4.897138E-18    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    4.249815E-18    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    8.851768E-18    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    7.702188E-18    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    5.920338E-18    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    6.902023E-18    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    6.697012E-18    0.000000E+00              9.00000E+100
#          25  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    5.603622E-18    0.000000E+00              9.00000E+100
#          26  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    5.173111E-18    0.000000E+00              9.00000E+100
#          27  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    3.793615E-18    0.000000E+00              9.00000E+100
#          28  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    4.368405E-18    0.000000E+00              9.00000E+100
#          29  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    4.221671E-18    0.000000E+00              9.00000E+100
#          30  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    9.569121E-19    0.000000E+00              9.00000E+100
#          31  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    4.109093E-18    0.000000E+00              9.00000E+100
#          32  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.174351E-17    0.000000E+00              9.00000E+100
#          33  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.040596E-17    0.000000E+00              9.00000E+100
#          34  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.040596E-17    0.000000E+00              9.00000E+100
#          35  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.946415E-17    0.000000E+00              9.00000E+100
#          36  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    9.402658E-17    0.000000E+00              9.00000E+100
#          37  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.137391E-17    0.000000E+00              9.00000E+100
#          38  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    1.571021E-16    0.000000E+00              9.00000E+100
#          39  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    6.561952E-17    0.000000E+00              9.00000E+100
#          40  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    1.013148E-16    0.000000E+00              9.00000E+100
#          41  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    6.094648E-17    0.000000E+00              9.00000E+100
#          42  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    5.303603E-17    0.000000E+00              9.00000E+100
#          43  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    7.676740E-17    0.000000E+00              9.00000E+100
#          44  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    1.663775E-17    0.000000E+00              9.00000E+100
#          45  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    4.137430E-18    0.000000E+00              9.00000E+100
#          46  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    6.223751E-17    0.000000E+00              9.00000E+100
#          47  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -7.211452E-18    0.000000E+00              9.00000E+100
#          48  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    2.253579E-18    0.000000E+00              9.00000E+100
#          49  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -5.408589E-18    0.000000E+00              9.00000E+100
#          50  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    1.426759E-17    0.000000E+00              9.00000E+100
#          51  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -4.602448E-18    0.000000E+00              9.00000E+100
#          52  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -2.761469E-18    0.000000E+00              9.00000E+100
#          53  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -1.532120E-17    0.000000E+00              9.00000E+100
#          54  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    6.566227E-18    0.000000E+00              9.00000E+100
#          55  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    5.471856E-19    0.000000E+00              9.00000E+100
#          56  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -1.058563E-17    0.000000E+00              9.00000E+100
#          57  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    2.301224E-18    0.000000E+00              9.00000E+100
#          58  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -6.443428E-18    0.000000E+00              9.00000E+100
#          59  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -3.831084E-18    0.000000E+00              9.00000E+100
#          60  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -3.155010E-18    0.000000E+00              9.00000E+100
#          61  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    3.605726E-18    0.000000E+00              9.00000E+100
#          62  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    3.057398E-17    0.000000E+00              9.00000E+100
#          63  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -9.108023E-18    0.000000E+00              9.00000E+100
#          64  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -3.348924E-17    0.000000E+00              9.00000E+100
#          65  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    8.004141E-18    0.000000E+00              9.00000E+100
#          66  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    2.547092E-17    0.000000E+00              9.00000E+100
#          67  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -1.052657E-17    0.000000E+00              9.00000E+100
#          68  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.753280E-17    0.000000E+00              9.00000E+100
#          69  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    5.872190E-18    0.000000E+00              9.00000E+100
#          70  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.916629E-17    0.000000E+00              9.00000E+100
#          71  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    4.183150E-17    0.000000E+00              9.00000E+100
#          72  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    4.134533E-17    0.000000E+00              9.00000E+100
#          73  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    7.581387E-18    0.000000E+00              9.00000E+100
#          74  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -3.613194E-17    0.000000E+00              9.00000E+100
#          75  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.890260E-17    0.000000E+00              9.00000E+100
#          76  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -2.295636E-17    0.000000E+00              9.00000E+100
#          77  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -3.603465E-18    0.000000E+00              9.00000E+100
#          78  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    6.253072E-18    0.000000E+00              9.00000E+100
#          79  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -9.291288E-18    0.000000E+00              9.00000E+100
#          80  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.669550E-17    0.000000E+00              9.00000E+100
#          81  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    8.585850E-18    0.000000E+00              9.00000E+100
#          82  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    7.142850E-18    0.000000E+00              9.00000E+100
#          83  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.316039E-18    0.000000E+00              9.00000E+100
#          84  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -1.389623E-17    0.000000E+00              9.00000E+100
#          85  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.376084E-17    0.000000E+00              9.00000E+100
#          86  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -2.922075E-18    0.000000E+00              9.00000E+100
#          87  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.597400E-18    0.000000E+00              9.00000E+100
#          88  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    1.601730E-17    0.000000E+00              9.00000E+100
#          89  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -4.469003E-18    0.000000E+00              9.00000E+100
#          90  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -4.221707E-18    0.000000E+00              9.00000E+100
#          91  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -2.384646E-18    0.000000E+00              9.00000E+100
#          92  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.857329E-01    1.000000E+00              9.00000E+100
#          93  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.437338E-01    1.000000E+00              9.00000E+100
#          94  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.078572E-01    1.000000E+00              9.00000E+100
#          95  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.001996E-01    1.000000E+00              9.00000E+100
#          96  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.001996E-01    1.000000E+00              9.00000E+100
#          97  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.826347E-01    1.000000E+00              9.00000E+100
#          98  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.948194E-01    1.000000E+00              9.00000E+100
#          99  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.037982E-01    1.000000E+00              9.00000E+100
#         100  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.037982E-01    1.000000E+00              9.00000E+100
#         101  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.451252E-01    1.000000E+00              9.00000E+100
#         102  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    6.246222E-01    1.000000E+00              9.00000E+100
#         103  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    6.547317E-01    1.000000E+00              9.00000E+100
#         104  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    6.547317E-01    1.000000E+00              9.00000E+100
#         105  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    7.197950E-01    1.000000E+00              9.00000E+100
#         106  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    8.281606E-01    1.000000E+00              9.00000E+100
#         107  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    8.671422E-01    1.000000E+00              9.00000E+100
#         108  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    8.671422E-01    1.000000E+00              9.00000E+100
#         109  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    9.155681E-01    1.000000E+00              9.00000E+100
#         110  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    9.782031E-01    1.000000E+00              9.00000E+100
#         111  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    9.999998E-01    1.000000E+00         u    9.00000E+100
#         112  traj.phases.cruise->initial_boundary_constraint->throttle    i   0.000000E+00    7.632495E-01    1.000000E+00              9.00000E+100
#         113  traj.phases.cruise->final_boundary_constraint->throttle      i   0.000000E+00    8.362885E-01    1.000000E+00              9.00000E+100
#         114  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.544803E-01    1.000000E+00              9.00000E+100
#         115  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.243655E-01    1.000000E+00              9.00000E+100
#         116  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    2.859180E-01    1.000000E+00              9.00000E+100
#         117  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    2.749855E-01    1.000000E+00              9.00000E+100
#         118  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    2.749855E-01    1.000000E+00              9.00000E+100
#         119  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    2.251696E-01    1.000000E+00              9.00000E+100
#         120  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.643848E-01    1.000000E+00              9.00000E+100
#         121  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.481745E-01    1.000000E+00              9.00000E+100
#         122  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.481745E-01    1.000000E+00              9.00000E+100
#         123  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.097710E-01    1.000000E+00              9.00000E+100
#         124  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    5.067860E-02    1.000000E+00              9.00000E+100
#         125  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.328127E-02    1.000000E+00              9.00000E+100
#         126  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.328127E-02    1.000000E+00              9.00000E+100
#         127  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    9.140031E-03    1.000000E+00              9.00000E+100
#         128  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.235415E-06    1.000000E+00              9.00000E+100
#         129  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    4.747193E-03    1.000000E+00              9.00000E+100
#         130  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    4.747193E-03    1.000000E+00              9.00000E+100
#         131  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.586570E-02    1.000000E+00              9.00000E+100
#         132  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    4.425440E-02    1.000000E+00              9.00000E+100
#         133  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    5.736927E-02    1.000000E+00              9.00000E+100
#
# --------------------------------------------------------------------------------

# %% [markdown]
# Now that we've run the case successfully, let's save and print out the fuel burn value:

# %%
fixed_mission_fixed_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
fixed_mission_fixed_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', fixed_mission_fixed_wing_fuel_burn)
print('Aspect ratio:', fixed_mission_fixed_wing_aspect_ratio)
# Out:
# Mission fuel burn, kg: 11398.915116162822
# Aspect ratio: 11.22091

# %% [markdown]
# ## Fixed Mission Profile, Optimized Aircraft Wing Aspect Ratio
#
# Now we will use the exact same `phase_info` object but set up our Aviary problem such that the aspect ratio of the wing is a design variable.
# This means that Aviary is optimizing the wing aspect ratio while flying the same mission profile as above.
# We would expect that by varying the wing aspect ratio, Aviary could find a lower fuel burn value.
#
# ```{note}
# All of the realistic design tradeoffs associated with varying the wing aspect ratio are not necessarily captured in this problem, e.g. the wing structure would need to change. We are simply using this as an example of an aircraft design variable available in Aviary.
# ```
#
# When we want to add an aircraft design variable to the Aviary problem, we need to use the Level 2 interface for Aviary.
# This means we can no longer use the all-inclusive `run_aviary` function and instead need to call its constituent methods individually.
# This allows us to insert a line adding the wing aspect ratio as a design variable as shown below.
# This line is highlighted with an in-line comment.

# %%
prob = av.AviaryProblem(phase_info, mission_method, mass_method, av.AnalysisScheme.COLLOCATION)

# Load aircraft and options data from user
# Allow for user overrides here
prob.load_inputs(aircraft_filename)

# Have checks for clashing user inputs
# Raise warnings or errors depending on how clashing the issues are
prob.check_inputs()

prob.add_pre_mission_systems()

prob.add_phases()

prob.add_post_mission_systems()

# Link phases and variables
prob.link_phases()

prob.add_driver(optimizer, max_iter=max_iter)

prob.add_design_variables()

# The following line is an example of how to add a design variable for the aspect ratio of the wing
prob.model.add_design_var(av.Aircraft.Wing.ASPECT_RATIO, lower=10., upper=14., ref=12.)

# Load optimization problem formulation
# Detail which variables the optimizer can control
prob.add_objective()

prob.setup()

prob.set_initial_guesses()

prob.run_aviary_problem(make_plots=make_plots)
# Out:
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
# /home/kmoore/Work/OpenMDAO/plugins/om-Aviary/aviary/subsystems/propulsion/engine_model.py:131: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
# /home/kmoore/Work/OpenMDAO/virtual_py38/lib/python3.8/site-packages/dymos/transcriptions/transcription_base.py:448: OpenMDAOWarning:'traj.phases.cruise' <class Phase>
#   Non-default solvers are required
#     implicit duration: False
#     solved segments: False
#     input initial: True
#   Setting `traj.phases.cruise.nonlinear_solver = om.NewtonSolver(iprint=0, solve_subsystems=True, maxiter=1000, stall_limit=3)`
#   Explicitly set traj.phases.cruise.nonlinear_solver to override.
#   Setting `traj.phases.cruise.linear_solver = om.DirectSolver(iprint=2)`
#   Explicitly set traj.phases.cruise.linear_solver to override.
#   Set `traj.phases.cruise.options["auto_solvers"] = False` to disable this behavior.
# /home/kmoore/Work/OpenMDAO/virtual_py38/lib/python3.8/site-packages/dymos/transcriptions/transcription_base.py:448: OpenMDAOWarning:'traj.phases.descent_1' <class Phase>
#   Non-default solvers are required
#     implicit duration: False
#     solved segments: False
#     input initial: True
#   Setting `traj.phases.descent_1.nonlinear_solver = om.NewtonSolver(iprint=0, solve_subsystems=True, maxiter=1000, stall_limit=3)`
#   Explicitly set traj.phases.descent_1.nonlinear_solver to override.
#   Setting `traj.phases.descent_1.linear_solver = om.DirectSolver(iprint=2)`
#   Explicitly set traj.phases.descent_1.linear_solver to override.
#   Set `traj.phases.descent_1.options["auto_solvers"] = False` to disable this behavior.
# Model viewer data has already been recorded for Driver.
# Model viewer data has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 0.493368 seconds.
# Total jacobian shape: (135, 95)
#
#
# Jacobian shape: (135, 95)  (14.41% nonzero)
# FWD solves: 22   REV solves: 0
# Total colors vs. total size: 22 vs 95  (76.84% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity:   0.4934 sec
# Time to compute coloring:   0.0730 sec
# Memory to compute coloring:   0.0000 MB
# Coloring created on: 2024-01-08 15:38:53
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                    9.7187
#        User Objective Time :       6.5665
#        User Sensitivity Time :     3.0612
#        Interface Time :            0.0562
#        Opt Solver Time:            0.0348
#     Calls to Objective Function :      25
#     Calls to Sens Function :           22
#
#
#    Objectives
#       Index  Name                   Value
#           0  fuel_burned     2.302861E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                             Type      Lower Bound            Value      Upper Bound     Status
#           0  mission:design:gross_mass_0         c     7.407407E-01     1.186031E+00     1.481481E+00
#           1  aircraft:wing:aspect_ratio_0        c     8.333333E-01     1.166667E+00     1.166667E+00          u
#           2  traj.climb_1.t_duration_0           c     5.000000E-01     6.465533E-01     1.500000E+00
#           3  traj.climb_1.states:mass_0          c     0.000000E+00     7.943528E+00     1.000000E+17
#           4  traj.climb_1.states:mass_1          c     0.000000E+00     7.927995E+00     1.000000E+17
#           5  traj.climb_1.states:mass_2          c     0.000000E+00     7.923353E+00     1.000000E+17
#           6  traj.climb_1.states:mass_3          c     0.000000E+00     7.902902E+00     1.000000E+17
#           7  traj.climb_1.states:mass_4          c     0.000000E+00     7.876832E+00     1.000000E+17
#           8  traj.climb_1.states:mass_5          c     0.000000E+00     7.868828E+00     1.000000E+17
#           9  traj.climb_1.states:mass_6          c     0.000000E+00     7.847375E+00     1.000000E+17
#          10  traj.climb_1.states:mass_7          c     0.000000E+00     7.817996E+00     1.000000E+17
#          11  traj.climb_1.states:mass_8          c     0.000000E+00     7.808642E+00     1.000000E+17
#          12  traj.climb_1.states:mass_9          c     0.000000E+00     7.790596E+00     1.000000E+17
#          13  traj.climb_1.states:mass_10         c     0.000000E+00     7.765534E+00     1.000000E+17
#          14  traj.climb_1.states:mass_11         c     0.000000E+00     7.757542E+00     1.000000E+17
#          15  traj.climb_1.states:mass_12         c     0.000000E+00     7.748557E+00     1.000000E+17
#          16  traj.climb_1.states:mass_13         c     0.000000E+00     7.736077E+00     1.000000E+17
#          17  traj.climb_1.states:mass_14         c     0.000000E+00     7.732101E+00     1.000000E+17
#          18  traj.climb_1.states:range_0         c     0.000000E+00     8.097358E-03     1.000000E+15
#          19  traj.climb_1.states:range_1         c     0.000000E+00     2.056882E-02     1.000000E+15
#          20  traj.climb_1.states:range_2         c     0.000000E+00     2.482703E-02     1.000000E+15
#          21  traj.climb_1.states:range_3         c     0.000000E+00     4.669938E-02     1.000000E+15
#          22  traj.climb_1.states:range_4         c     0.000000E+00     8.207570E-02     1.000000E+15
#          23  traj.climb_1.states:range_5         c     0.000000E+00     9.450124E-02     1.000000E+15
#          24  traj.climb_1.states:range_6         c     0.000000E+00     1.312534E-01     1.000000E+15
#          25  traj.climb_1.states:range_7         c     0.000000E+00     1.888000E-01     1.000000E+15
#          26  traj.climb_1.states:range_8         c     0.000000E+00     2.086184E-01     1.000000E+15
#          27  traj.climb_1.states:range_9         c     0.000000E+00     2.489030E-01     1.000000E+15
#          28  traj.climb_1.states:range_10        c     0.000000E+00     3.089323E-01     1.000000E+15
#          29  traj.climb_1.states:range_11        c     0.000000E+00     3.289761E-01     1.000000E+15
#          30  traj.climb_1.states:range_12        c     0.000000E+00     3.520331E-01     1.000000E+15
#          31  traj.climb_1.states:range_13        c     0.000000E+00     3.848425E-01     1.000000E+15
#          32  traj.climb_1.states:range_14        c     0.000000E+00     3.954634E-01     1.000000E+15
#          33  traj.cruise.t_duration_0            c     5.000000E-01     1.233389E+00     1.500000E+00
#          34  traj.cruise.states:mass_0           c     0.000000E+00     7.700320E+00     1.000000E+17
#          35  traj.cruise.states:mass_1           c     0.000000E+00     7.656499E+00     1.000000E+17
#          36  traj.cruise.states:mass_2           c     0.000000E+00     7.642637E+00     1.000000E+17
#          37  traj.cruise.states:mass_3           c     0.000000E+00     7.577848E+00     1.000000E+17
#          38  traj.cruise.states:mass_4           c     0.000000E+00     7.488538E+00     1.000000E+17
#          39  traj.cruise.states:mass_5           c     0.000000E+00     7.460286E+00     1.000000E+17
#          40  traj.cruise.states:mass_6           c     0.000000E+00     7.383369E+00     1.000000E+17
#          41  traj.cruise.states:mass_7           c     0.000000E+00     7.277121E+00     1.000000E+17
#          42  traj.cruise.states:mass_8           c     0.000000E+00     7.243427E+00     1.000000E+17
#          43  traj.cruise.states:mass_9           c     0.000000E+00     7.178414E+00     1.000000E+17
#          44  traj.cruise.states:mass_10          c     0.000000E+00     7.088107E+00     1.000000E+17
#          45  traj.cruise.states:mass_11          c     0.000000E+00     7.059291E+00     1.000000E+17
#          46  traj.cruise.states:mass_12          c     0.000000E+00     7.026911E+00     1.000000E+17
#          47  traj.cruise.states:mass_13          c     0.000000E+00     6.982031E+00     1.000000E+17
#          48  traj.cruise.states:mass_14          c     0.000000E+00     6.967758E+00     1.000000E+17
#          49  traj.cruise.states:range_0          c     0.000000E+00     5.176586E-01     1.000000E+15
#          50  traj.cruise.states:range_1          c     0.000000E+00     6.870600E-01     1.000000E+15
#          51  traj.cruise.states:range_2          c     0.000000E+00     7.408673E-01     1.000000E+15
#          52  traj.cruise.states:range_3          c     0.000000E+00     9.937279E-01     1.000000E+15
#          53  traj.cruise.states:range_4          c     0.000000E+00     1.345927E+00     1.000000E+15
#          54  traj.cruise.states:range_5          c     0.000000E+00     1.458192E+00     1.000000E+15
#          55  traj.cruise.states:range_6          c     0.000000E+00     1.765762E+00     1.000000E+15
#          56  traj.cruise.states:range_7          c     0.000000E+00     2.194766E+00     1.000000E+15
#          57  traj.cruise.states:range_8          c     0.000000E+00     2.331657E+00     1.000000E+15
#          58  traj.cruise.states:range_9          c     0.000000E+00     2.596819E+00     1.000000E+15
#          59  traj.cruise.states:range_10         c     0.000000E+00     2.965922E+00     1.000000E+15
#          60  traj.cruise.states:range_11         c     0.000000E+00     3.083521E+00     1.000000E+15
#          61  traj.cruise.states:range_12         c     0.000000E+00     3.215822E+00     1.000000E+15
#          62  traj.cruise.states:range_13         c     0.000000E+00     3.399140E+00     1.000000E+15
#          63  traj.cruise.states:range_14         c     0.000000E+00     3.457345E+00     1.000000E+15
#          64  traj.descent_1.t_duration_0         c     5.000000E-01     9.012910E-01     1.500000E+00
#          65  traj.descent_1.states:mass_0        c     0.000000E+00     6.964703E+00     1.000000E+17
#          66  traj.descent_1.states:mass_1        c     0.000000E+00     6.960565E+00     1.000000E+17
#          67  traj.descent_1.states:mass_2        c     0.000000E+00     6.959272E+00     1.000000E+17
#          68  traj.descent_1.states:mass_3        c     0.000000E+00     6.953377E+00     1.000000E+17
#          69  traj.descent_1.states:mass_4        c     0.000000E+00     6.945686E+00     1.000000E+17
#          70  traj.descent_1.states:mass_5        c     0.000000E+00     6.943373E+00     1.000000E+17
#          71  traj.descent_1.states:mass_6        c     0.000000E+00     6.937368E+00     1.000000E+17
#          72  traj.descent_1.states:mass_7        c     0.000000E+00     6.930135E+00     1.000000E+17
#          73  traj.descent_1.states:mass_8        c     0.000000E+00     6.928175E+00     1.000000E+17
#          74  traj.descent_1.states:mass_9        c     0.000000E+00     6.924466E+00     1.000000E+17
#          75  traj.descent_1.states:mass_10       c     0.000000E+00     6.919298E+00     1.000000E+17
#          76  traj.descent_1.states:mass_11       c     0.000000E+00     6.917556E+00     1.000000E+17
#          77  traj.descent_1.states:mass_12       c     0.000000E+00     6.915510E+00     1.000000E+17
#          78  traj.descent_1.states:mass_13       c     0.000000E+00     6.912473E+00     1.000000E+17
#          79  traj.descent_1.states:mass_14       c     0.000000E+00     6.911450E+00     1.000000E+17
#          80  traj.descent_1.states:range_0       c     0.000000E+00     3.481035E+00     1.000000E+15
#          81  traj.descent_1.states:range_1       c     0.000000E+00     3.512810E+00     1.000000E+15
#          82  traj.descent_1.states:range_2       c     0.000000E+00     3.522643E+00     1.000000E+15
#          83  traj.descent_1.states:range_3       c     0.000000E+00     3.567157E+00     1.000000E+15
#          84  traj.descent_1.states:range_4       c     0.000000E+00     3.624485E+00     1.000000E+15
#          85  traj.descent_1.states:range_5       c     0.000000E+00     3.641608E+00     1.000000E+15
#          86  traj.descent_1.states:range_6       c     0.000000E+00     3.685654E+00     1.000000E+15
#          87  traj.descent_1.states:range_7       c     0.000000E+00     3.740048E+00     1.000000E+15
#          88  traj.descent_1.states:range_8       c     0.000000E+00     3.755671E+00     1.000000E+15
#          89  traj.descent_1.states:range_9       c     0.000000E+00     3.783538E+00     1.000000E+15
#          90  traj.descent_1.states:range_10      c     0.000000E+00     3.817063E+00     1.000000E+15
#          91  traj.descent_1.states:range_11      c     0.000000E+00     3.826454E+00     1.000000E+15
#          92  traj.descent_1.states:range_12      c     0.000000E+00     3.836273E+00     1.000000E+15
#          93  traj.descent_1.states:range_13      c     0.000000E+00     3.848572E+00     1.000000E+15
#          94  traj.descent_1.states:range_14      c     0.000000E+00     3.852160E+00     1.000000E+15
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                      Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  mission:constraints:range_residual                           e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  mission:constraints:mass_residual                            e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           2  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.455597E-17    0.000000E+00              9.00000E+100
#           3  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -9.597735E-18    0.000000E+00              9.00000E+100
#           4  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.355164E-18    0.000000E+00              9.00000E+100
#           5  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.263914E-17    0.000000E+00              9.00000E+100
#           6  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    1.768457E-17    0.000000E+00              9.00000E+100
#           7  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -9.294345E-18    0.000000E+00              9.00000E+100
#           8  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    1.100706E-17    0.000000E+00              9.00000E+100
#           9  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    2.764664E-17    0.000000E+00              9.00000E+100
#          10  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -2.566881E-17    0.000000E+00              9.00000E+100
#          11  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -9.294345E-18    0.000000E+00              9.00000E+100
#          12  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    2.296463E-17    0.000000E+00              9.00000E+100
#          13  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    1.117491E-17    0.000000E+00              9.00000E+100
#          14  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.119677E-16    0.000000E+00              9.00000E+100
#          15  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00    2.479120E-18    0.000000E+00              9.00000E+100
#          16  traj.climb_1.collocation_constraint.defects:mass             e   0.000000E+00   -1.352891E-17    0.000000E+00              9.00000E+100
#          17  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    2.266624E-20    0.000000E+00              9.00000E+100
#          18  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          19  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -6.799871E-20    0.000000E+00              9.00000E+100
#          20  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -4.629090E-19    0.000000E+00              9.00000E+100
#          21  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    2.777454E-19    0.000000E+00              9.00000E+100
#          22  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -4.166181E-19    0.000000E+00              9.00000E+100
#          23  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    1.265812E-18    0.000000E+00              9.00000E+100
#          24  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -9.906354E-19    0.000000E+00              9.00000E+100
#          25  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    5.503530E-19    0.000000E+00              9.00000E+100
#          26  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -6.480726E-19    0.000000E+00              9.00000E+100
#          27  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    1.666472E-18    0.000000E+00              9.00000E+100
#          28  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -2.036800E-18    0.000000E+00              9.00000E+100
#          29  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00    2.765281E-18    0.000000E+00              9.00000E+100
#          30  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -2.266624E-19    0.000000E+00              9.00000E+100
#          31  traj.climb_1.collocation_constraint.defects:range            e   0.000000E+00   -3.173273E-19    0.000000E+00              9.00000E+100
#          32  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -2.075324E-17    0.000000E+00              9.00000E+100
#          33  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -1.254026E-17    0.000000E+00              9.00000E+100
#          34  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.861298E-17    0.000000E+00              9.00000E+100
#          35  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.146255E-17    0.000000E+00              9.00000E+100
#          36  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    9.739307E-18    0.000000E+00              9.00000E+100
#          37  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.200362E-17    0.000000E+00              9.00000E+100
#          38  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    5.832422E-17    0.000000E+00              9.00000E+100
#          39  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    3.001982E-18    0.000000E+00              9.00000E+100
#          40  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -1.007808E-17    0.000000E+00              9.00000E+100
#          41  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    3.030007E-17    0.000000E+00              9.00000E+100
#          42  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    1.803575E-19    0.000000E+00              9.00000E+100
#          43  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -2.020004E-17    0.000000E+00              9.00000E+100
#          44  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -3.090909E-18    0.000000E+00              9.00000E+100
#          45  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00    2.057662E-17    0.000000E+00              9.00000E+100
#          46  traj.cruise.collocation_constraint.defects:mass              e   0.000000E+00   -1.854545E-18    0.000000E+00              9.00000E+100
#          47  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -2.486857E-18    0.000000E+00              9.00000E+100
#          48  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    6.782337E-19    0.000000E+00              9.00000E+100
#          49  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -2.260779E-18    0.000000E+00              9.00000E+100
#          50  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -1.385146E-18    0.000000E+00              9.00000E+100
#          51  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    3.232007E-18    0.000000E+00              9.00000E+100
#          52  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    4.617153E-18    0.000000E+00              9.00000E+100
#          53  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -1.866375E-17    0.000000E+00              9.00000E+100
#          54  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    5.489338E-19    0.000000E+00              9.00000E+100
#          55  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -5.489338E-18    0.000000E+00              9.00000E+100
#          56  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -9.696022E-18    0.000000E+00              9.00000E+100
#          57  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    2.770292E-18    0.000000E+00              9.00000E+100
#          58  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -6.925730E-18    0.000000E+00              9.00000E+100
#          59  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    1.130389E-18    0.000000E+00              9.00000E+100
#          60  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00    5.199792E-18    0.000000E+00              9.00000E+100
#          61  traj.cruise.collocation_constraint.defects:range             e   0.000000E+00   -2.283387E-17    0.000000E+00              9.00000E+100
#          62  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -5.253461E-17    0.000000E+00              9.00000E+100
#          63  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    3.254872E-17    0.000000E+00              9.00000E+100
#          64  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -3.919599E-17    0.000000E+00              9.00000E+100
#          65  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    4.441785E-17    0.000000E+00              9.00000E+100
#          66  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    9.578555E-18    0.000000E+00              9.00000E+100
#          67  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.037077E-17    0.000000E+00              9.00000E+100
#          68  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    3.125265E-18    0.000000E+00              9.00000E+100
#          69  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -1.026414E-17    0.000000E+00              9.00000E+100
#          70  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.905128E-18    0.000000E+00              9.00000E+100
#          71  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -1.940918E-17    0.000000E+00              9.00000E+100
#          72  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    1.218025E-17    0.000000E+00              9.00000E+100
#          73  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -2.953688E-17    0.000000E+00              9.00000E+100
#          74  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -2.238826E-17    0.000000E+00              9.00000E+100
#          75  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00    2.113198E-17    0.000000E+00              9.00000E+100
#          76  traj.descent_1.collocation_constraint.defects:mass           e   0.000000E+00   -4.639426E-17    0.000000E+00              9.00000E+100
#          77  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.608975E-17    0.000000E+00              9.00000E+100
#          78  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -4.017280E-18    0.000000E+00              9.00000E+100
#          79  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -1.006577E-17    0.000000E+00              9.00000E+100
#          80  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -3.779568E-18    0.000000E+00              9.00000E+100
#          81  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -1.014030E-18    0.000000E+00              9.00000E+100
#          82  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -1.843692E-18    0.000000E+00              9.00000E+100
#          83  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.959155E-18    0.000000E+00              9.00000E+100
#          84  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    5.479918E-19    0.000000E+00              9.00000E+100
#          85  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.411164E-18    0.000000E+00              9.00000E+100
#          86  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -1.613230E-17    0.000000E+00              9.00000E+100
#          87  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -7.282582E-18    0.000000E+00              9.00000E+100
#          88  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    9.633289E-18    0.000000E+00              9.00000E+100
#          89  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -2.850463E-17    0.000000E+00              9.00000E+100
#          90  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00    2.302037E-18    0.000000E+00              9.00000E+100
#          91  traj.descent_1.collocation_constraint.defects:range          e   0.000000E+00   -2.369744E-18    0.000000E+00              9.00000E+100
#          92  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.022807E-01    1.000000E+00              9.00000E+100
#          93  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.778039E-01    1.000000E+00              9.00000E+100
#          94  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.596245E-01    1.000000E+00              9.00000E+100
#          95  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.564909E-01    1.000000E+00              9.00000E+100
#          96  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.564909E-01    1.000000E+00              9.00000E+100
#          97  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.553331E-01    1.000000E+00              9.00000E+100
#          98  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.820211E-01    1.000000E+00              9.00000E+100
#          99  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.944016E-01    1.000000E+00              9.00000E+100
#         100  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    4.944016E-01    1.000000E+00              9.00000E+100
#         101  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    5.426631E-01    1.000000E+00              9.00000E+100
#         102  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    6.279082E-01    1.000000E+00              9.00000E+100
#         103  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    6.589602E-01    1.000000E+00              9.00000E+100
#         104  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    6.589602E-01    1.000000E+00              9.00000E+100
#         105  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    7.241358E-01    1.000000E+00              9.00000E+100
#         106  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    8.306204E-01    1.000000E+00              9.00000E+100
#         107  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    8.692410E-01    1.000000E+00              9.00000E+100
#         108  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    8.692410E-01    1.000000E+00              9.00000E+100
#         109  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    9.169702E-01    1.000000E+00              9.00000E+100
#         110  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    9.787680E-01    1.000000E+00              9.00000E+100
#         111  traj.phases.climb_1->path_constraint->throttle               i   0.000000E+00    9.999996E-01    1.000000E+00         u    9.00000E+100
#         112  traj.phases.cruise->initial_boundary_constraint->throttle    i   0.000000E+00    7.018016E-01    1.000000E+00              9.00000E+100
#         113  traj.phases.cruise->final_boundary_constraint->throttle      i   0.000000E+00    8.020302E-01    1.000000E+00              9.00000E+100
#         114  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.841657E-01    1.000000E+00              9.00000E+100
#         115  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.536026E-01    1.000000E+00              9.00000E+100
#         116  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.144874E-01    1.000000E+00              9.00000E+100
#         117  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.033857E-01    1.000000E+00              9.00000E+100
#         118  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.033857E-01    1.000000E+00              9.00000E+100
#         119  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    2.553244E-01    1.000000E+00              9.00000E+100
#         120  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.944066E-01    1.000000E+00              9.00000E+100
#         121  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.778796E-01    1.000000E+00              9.00000E+100
#         122  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.778796E-01    1.000000E+00              9.00000E+100
#         123  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.381153E-01    1.000000E+00              9.00000E+100
#         124  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    8.906587E-02    1.000000E+00              9.00000E+100
#         125  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    6.748586E-02    1.000000E+00              9.00000E+100
#         126  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    6.748586E-02    1.000000E+00              9.00000E+100
#         127  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.312964E-02    1.000000E+00              9.00000E+100
#         128  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    3.841016E-03    1.000000E+00              9.00000E+100
#         129  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.506090E-04    1.000000E+00              9.00000E+100
#         130  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.506090E-04    1.000000E+00              9.00000E+100
#         131  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.004515E-06    1.000000E+00              9.00000E+100
#         132  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    8.451559E-03    1.000000E+00              9.00000E+100
#         133  traj.phases.descent_1->path_constraint->throttle             i   0.000000E+00    1.377076E-02    1.000000E+00              9.00000E+100
#
# --------------------------------------------------------------------------------
# False

# %%
fixed_mission_optimized_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
fixed_mission_optimized_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', fixed_mission_optimized_wing_fuel_burn)
print('Aspect ratio:', fixed_mission_optimized_wing_aspect_ratio)
# Out:
# Mission fuel burn, kg: 10445.603333465715
# Aspect ratio: 13.99999830092345

# %% [markdown]
# As expected, the optimal fuel burn value is lower for this case.
# We'll discuss this in more detail after running two more cases.
#
# ## Optimized Mission Profile, Fixed Aircraft Wing Aspect Ratio
#
# We just investigated giving the optimizer flexibility with the aircraft design while not varying the mission.
# Let's now look at the results when we optimize the mission but keep the wing aspect ratio unchanged.
#
# To do this, we will allow the optimizer to control the Mach and altitude profiles by modifying the `phase_info` object:

# %%
phase_info['climb_1']['user_options']['optimize_mach'] = True
phase_info['climb_1']['user_options']['optimize_altitude'] = True
phase_info['cruise']['user_options']['optimize_mach'] = True
phase_info['cruise']['user_options']['optimize_altitude'] = True
phase_info['descent_1']['user_options']['optimize_mach'] = True
phase_info['descent_1']['user_options']['optimize_altitude'] = True

prob = av.run_aviary(aircraft_filename, phase_info,
                    mission_method=mission_method, mass_method=mass_method,
                    optimizer=optimizer, make_plots=make_plots, max_iter=max_iter)
# Out:
# The following variables have been overridden:
#   'aircraft:design:touchdown_mass
#   'aircraft:engine:mass
#   'aircraft:fins:mass
#   'aircraft:fuel:auxiliary_fuel_capacity
#   'aircraft:fuel:fuselage_fuel_capacity
#   'aircraft:fuel:total_capacity
#   'aircraft:fuselage:planform_area
#   'aircraft:fuselage:wetted_area
#   'aircraft:horizontal_tail:wetted_area
#   'aircraft:landing_gear:main_gear_oleo_length
#   'aircraft:landing_gear:nose_gear_oleo_length
#   'aircraft:vertical_tail:wetted_area
#   'aircraft:wing:aspect_ratio
#   'aircraft:wing:control_surface_area
#   'aircraft:wing:wetted_area
# /home/kmoore/Work/OpenMDAO/plugins/om-Aviary/aviary/subsystems/propulsion/engine_model.py:131: UserWarning: The value of aircraft:engine:wing_locations passed to EngineModel <engine_deck> is type <class 'numpy.ndarray'>. Only the first entry in this iterable will be used.
#   warnings.warn(
# --- Constraint Report [traj] ---
#     --- climb_1 ---
#         [initial] 2.0000e-01 == mach [unitless]
#         [initial] 0.0000e+00 == altitude [ft]
#         [path]    0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- cruise ---
#         [initial] 0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#         [final]   0.0000e+00 <= throttle <= 1.0000e+00  [unitless]
#     --- descent_1 ---

# %% [markdown]
# Now, let's see the fuel burn:

# %%
optimized_mission_fixed_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
optimized_mission_fixed_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', optimized_mission_fixed_wing_fuel_burn)
print('Aspect ratio:', optimized_mission_fixed_wing_aspect_ratio)

# %% [markdown]
# Optimizing the mission did not have nearly as large of an impact on the fuel burn as optimizing the aspect ratio did.
# However, the fuel burn still decreased.
# Let us now look at the fully coupled case.
#
# ## Optimized Mission Profile, Optimized Aircraft Wing Aspect Ratio
#
# Remember we have already modified the `phase_info` object so that the Mach and altitude profiles are optimized.
# Now we return to the Level 2 way of running the problem with the wing aspect ratio as a design variable.

# %%
prob = av.AviaryProblem(phase_info, mission_method, mass_method, av.AnalysisScheme.COLLOCATION)

# Load aircraft and options data from user
# Allow for user overrides here
prob.load_inputs(aircraft_filename)

# Have checks for clashing user inputs
# Raise warnings or errors depending on how clashing the issues are
prob.check_inputs()

prob.add_pre_mission_systems()

prob.add_phases()

prob.add_post_mission_systems()

# Link phases and variables
prob.link_phases()

prob.add_driver(optimizer, max_iter=max_iter)

prob.add_design_variables()

# prob.model.add_design_var(av.Aircraft.Engine.SCALED_SLS_THRUST, lower=25.e3, upper=30.e3, units='lbf', ref=28.e3)
prob.model.add_design_var(av.Aircraft.Wing.ASPECT_RATIO, lower=10., upper=14., ref=12.)

# Load optimization problem formulation
# Detail which variables the optimizer can control
prob.add_objective()

prob.setup()

prob.set_initial_guesses()

prob.run_aviary_problem(make_plots=make_plots)

# %% [markdown]
# All right, let's check out this final case's fuel burn value:

# %%
optimized_mission_optimized_wing_fuel_burn = prob.get_val('fuel_burned', units='kg')[0]
optimized_mission_optimized_wing_aspect_ratio = prob.get_val(av.Aircraft.Wing.ASPECT_RATIO)[0]
print('Mission fuel burn, kg:', optimized_mission_optimized_wing_fuel_burn)
print('Aspect ratio:', optimized_mission_optimized_wing_aspect_ratio)

# %% [markdown]
# Cool, it's the lowest yet!
# Let's discuss these results in more detail now.
#
# ## Summary and Takeaways
#
# We have showcased one of Aviary's most powerful capabilities here -- the ability to simultaneously design an aircraft and optimal trajectory.
# By building up problem complexity, we can see how optimizing different parts of the problem lead to optimization objective improvements.
#
# Here is a summary table of the results:

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Case': ['Fixed Mission, Fixed Wing', 'Fixed Mission, Optimized Wing', 'Optimized Mission, Fixed Wing', 'Optimized Mission, Optimized Wing'],
    'Optimize Mission': ['-', '-', '✓', '✓'],
    'Optimize Wing': ['-', '✓', '-', '✓'],
    'Aspect Ratio': [fixed_mission_fixed_wing_aspect_ratio, fixed_mission_optimized_wing_aspect_ratio, optimized_mission_fixed_wing_aspect_ratio, optimized_mission_optimized_wing_aspect_ratio],
    'Fuel Burn Value': [fixed_mission_fixed_wing_fuel_burn, fixed_mission_optimized_wing_fuel_burn, optimized_mission_fixed_wing_fuel_burn, optimized_mission_optimized_wing_fuel_burn]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data).round(2)

# Display the DataFrame
df

# %% [markdown]
# We see that the fully coupled case finds the lowest fuel burn value, as expected.
# In both cases where the wing aspect ratio is optimized, it moves to the higher bound.
#
# If we didn't simultaneously design the aircraft and the mission, you would have to manually iterate by first optimizing the aircraft, then the mission, then the aircraft again, etc.
# This cumbersome process is known as sequential optimization and can lead to non-optimal results for coupled systems, as detailed in [Section 13.1 of the free Engineering Design Optimization textbook](https://flowlab.groups.et.byu.net/mdobook.pdf).
#
# Aviary is unique in its ability to solve these coupled systems using efficient gradient-based optimization.
#
# This doc page contains a simple example, but the true power of coupled multidisciplinary optimization lies in solving more complex design problems.
# We hope that you can effectively use Aviary to optimally design the next generation of exciting aircraft!
